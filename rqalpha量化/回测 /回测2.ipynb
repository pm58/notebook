# %%
from matplotlib import rcParams
import matplotlib.pyplot as plt
import numpy as np
np.seterr(all='ignore')
rcParams['figure.figsize'] = (14, 6)
from funcat import * #FUNCAT的同花顺/通达信指标模块：和：&，或：|，其他基本相同。可以使用指标选股！！！
from tushare import * #TUSHARE数据连接更新。
from rqalpha import * #RQALPHA本地数据连接，通过 rqalpha update_bundle 8点后更新全部数据库
from funcat.data.tushare_backend import TushareDataBackend
from funcat.data.rqalpha_data_backend import RQAlphaDataBackend
backend = "tushare"
if backend == "rqalpha":
    set_data_backend(RQAlphaDataBackend("~/.rqalpha/bundle"))
elif backend == "tushare":
    set_data_backend(TushareDataBackend())
set_start_date(20170101)
#S("000001.XSHG")  # 设置当前关注股票
#T("20080202")   # 设置当前观察日期    

def callback(date, order_book_id,symbol):
    print(date,order_book_id,symbol) 
select(
    lambda : O / H[1] - 1 >= 0.0995,
    start_date=("20180205"),
    end_date=("20180206"),
    callback=callback,
)

#def callback(date, order_book_id, symbol):
#    print("Cool, 在", date, "选出", order_book_id, symbol)    
#select(
#    lambda : (EVERY(V < MA(V, 20) / 2, 3) & EVERY(L < MA(C, 20), 3) & EVERY(H > MA(C, 20), 3)),
#    start_date=(n3),
#	end_date=(n2),
#    callback=callback,
#)
# Out:
# lambda : O / H[1] - 1 >= 0.0995,
# [20180205]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-42b75f9413b8> in <module>()
#      24     start_date=("20180205"),
#      25     end_date=("20180206"),
# ---> 26     callback=callback,
#      27 )
#      28
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/funcat/helper.py in wrapper(*args, **kwargs)
#      15         try:
#      16             old_settings = np.seterr(all='ignore')
# ---> 17             return func(*args, **kwargs)
#      18         finally:
#      19             np.seterr(**old_settings)  # reset to default
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/funcat/helper.py in select(func, start_date, end_date, callback)
#      49
#      50         for order_book_id in order_book_id_list:
# ---> 51             choose(order_book_id, func, callback)
#      52
#      53     print("")
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/funcat/helper.py in choose(order_book_id, func, callback)
#      24     set_current_security(order_book_id)
#      25     try:
# ---> 26         if func():
#      27             date = ExecutionContext.get_current_date()
#      28             callback(date, order_book_id, symbol(order_book_id))
#
# <ipython-input-1-42b75f9413b8> in <lambda>()
#      21     print(date,order_book_id,symbol)
#      22 select(
# ---> 23     lambda : O / H[1] - 1 >= 0.0995,
#      24     start_date=("20180205"),
#      25     end_date=("20180206"),
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/funcat/time_series.py in __getitem__(self, index)
#     266             return time_series
#     267
# --> 268         return self.__class__(series=self.series[:len(self.series) - index], **self.extra_create_kwargs)
#     269
#     270     @property
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/funcat/time_series.py in series(self)
#     270     @property
#     271     def series(self):
# --> 272         self._ensure_series_update()
#     273         return super(MarketDataSeries, self).series
#     274
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/funcat/time_series.py in _ensure_series_update(self)
#     246             # TODO: cache
#     247             freq = self._freq if self._freq is not None else ExecutionContext.get_current_freq()
# --> 248             bars = get_bars(freq)
#     249             if len(bars) > 0:
#     250                 self._series = bars[self.name].astype(self.dtype)
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/funcat/time_series.py in get_bars(freq)
#      18
#      19     try:
# ---> 20         bars = data_backend.get_price(order_book_id, start=start_date, end=current_date, freq=freq)
#      21     except KeyError:
#      22         return np.array([])
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/funcat/data/tushare_backend.py in get_price(self, order_book_id, start, end, freq)
#      57         # else W M
#      58
# ---> 59         df = self.ts.get_k_data(code, start=start, end=end, index=is_index, ktype=ktype)
#      60
#      61         if freq[-1] == "m":
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/tushare/stock/trading.py in get_k_data(code, start, end, ktype, autype, index, retry_count, pause)
#     695                                        symbol, code,
#     696                                        index, ktype,
# --> 697                                        retry_count, pause),
#     698                            ignore_index=True)
#     699     if ktype not in ct.K_MIN_LABELS:
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/tushare/stock/trading.py in _get_k_data(url, dataflag, symbol, code, index, ktype, retry_count, pause)
#     716             try:
#     717                 request = Request(url)
# --> 718                 lines = urlopen(request, timeout = 10).read()
#     719                 if len(lines) < 100: #no data
#     720                     return None
#
# ~/anaconda3/envs/THS/lib/python3.5/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     161     else:
#     162         opener = _opener
# --> 163     return opener.open(url, data, timeout)
#     164
#     165 def install_opener(opener):
#
# ~/anaconda3/envs/THS/lib/python3.5/urllib/request.py in open(self, fullurl, data, timeout)
#     464             req = meth(req)
#     465
# --> 466         response = self._open(req, data)
#     467
#     468         # post-process response
#
# ~/anaconda3/envs/THS/lib/python3.5/urllib/request.py in _open(self, req, data)
#     482         protocol = req.type
#     483         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 484                                   '_open', req)
#     485         if result:
#     486             return result
#
# ~/anaconda3/envs/THS/lib/python3.5/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     442         for handler in handlers:
#     443             func = getattr(handler, meth_name)
# --> 444             result = func(*args)
#     445             if result is not None:
#     446                 return result
#
# ~/anaconda3/envs/THS/lib/python3.5/urllib/request.py in http_open(self, req)
#    1280
#    1281     def http_open(self, req):
# -> 1282         return self.do_open(http.client.HTTPConnection, req)
#    1283
#    1284     http_request = AbstractHTTPHandler.do_request_
#
# ~/anaconda3/envs/THS/lib/python3.5/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1252         try:
#    1253             try:
# -> 1254                 h.request(req.get_method(), req.selector, req.data, headers)
#    1255             except OSError as err: # timeout error
#    1256                 raise URLError(err)
#
# ~/anaconda3/envs/THS/lib/python3.5/http/client.py in request(self, method, url, body, headers)
#    1105     def request(self, method, url, body=None, headers={}):
#    1106         """Send a complete request to the server."""
# -> 1107         self._send_request(method, url, body, headers)
#    1108
#    1109     def _set_content_length(self, body, method):
#
# ~/anaconda3/envs/THS/lib/python3.5/http/client.py in _send_request(self, method, url, body, headers)
#    1150             # default charset of iso-8859-1.
#    1151             body = _encode(body, 'body')
# -> 1152         self.endheaders(body)
#    1153
#    1154     def getresponse(self):
#
# ~/anaconda3/envs/THS/lib/python3.5/http/client.py in endheaders(self, message_body)
#    1101         else:
#    1102             raise CannotSendHeader()
# -> 1103         self._send_output(message_body)
#    1104
#    1105     def request(self, method, url, body=None, headers={}):
#
# ~/anaconda3/envs/THS/lib/python3.5/http/client.py in _send_output(self, message_body)
#     932         del self._buffer[:]
#     933
# --> 934         self.send(msg)
#     935         if message_body is not None:
#     936             self.send(message_body)
#
# ~/anaconda3/envs/THS/lib/python3.5/http/client.py in send(self, data)
#     875         if self.sock is None:
#     876             if self.auto_open:
# --> 877                 self.connect()
#     878             else:
#     879                 raise NotConnected()
#
# ~/anaconda3/envs/THS/lib/python3.5/http/client.py in connect(self)
#     847         """Connect to the host and port specified in __init__."""
#     848         self.sock = self._create_connection(
# --> 849             (self.host,self.port), self.timeout, self.source_address)
#     850         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#     851
#
# ~/anaconda3/envs/THS/lib/python3.5/socket.py in create_connection(address, timeout, source_address)
#     701             if source_address:
#     702                 sock.bind(source_address)
# --> 703             sock.connect(sa)
#     704             return sock
#     705
#
# KeyboardInterrupt:
