# %%
#测试模块！！！

import matplotlib 
print ("matplotlib",matplotlib.__version__)
#import matplotlib.pyplot as plt
import numpy 
print ("numpy",numpy.__version__)
#np.seterr(all='ignore')
#rcParams['figure.figsize'] = (14, 6)
import funcat  #FUNCAT的同花顺/通达信指标模块：和：&，或：|，其他基本相同。可以使用指标选股！！！
print("funcat",funcat.__version__)
#from pytdx import * #通达信数据更新模块到QUANTAXIS的mongoDB
#pttdx.__version__
import tushare  #TUSHARE数据连接更新。
print ("tushare",tushare.__version__)
import rqalpha #RQALPHA本地数据连接，通过 rqalpha update_bundle 8点后更新全部数据库
print("rqalpha",rqalpha.__version__)
# Out:
# matplotlib 2.1.2
# numpy 1.14.0
# funcat 0.3.2
# tushare 1.1.3
# rqalpha 3.0.9

# %%
#CCI选股！

#from matplotlib import rcParams
#import matplotlib.pyplot as plt
#import numpy as np
#np.seterr(all='ignore')
#rcParams['figure.figsize'] = (14, 6)

from funcat import * #FUNCAT的同花顺/通达信指标模块：和：&，或：|，其他基本相同。可以使用指标选股！！！
from tushare import * #TUSHARE数据连接更新。
from rqalpha import * #RQALPHA本地数据连接，通过 rqalpha update_bundle 8点后更新全部数据库

import time
import datetime #读取/设定数据库时间区域，当前股票，选股时间段。 

n1 = (time.strftime("20%y-%m-%d"))## 20yy-mm-dd格式，输出当日日期
print ("《设定测试》读取当日时间格式：n1",n1) #当日时间格式：yyyy-mm-dd
n2 = (time.strftime("20%y%m%d"))## 20yymmdd格式，输出当日日期
print ("《设定测试》读取当日时间格式：n2",n2) #当日时间格式：yyyymmdd
def getYesterday(): 
    today=datetime.date.today() 
    oneday=datetime.timedelta(days=1) 
    yesterday=today-oneday  
    return yesterday
n3 = (getYesterday())# 输出前二天日期
print ("《设定测试》读取前二日时间格式：n3",n3) #前日时间格式：yyyy-mm-dd
i = datetime.datetime.now()#当前日期

n4 = ("%s%s%s" % (i.year, i.month, i.day) )
print ("《设定测试》读取当日时间格式：n4",n4) #当日时间格式：yyyymmdd

n5 = ("%s" % i.isoformat() )
print ("《设定测试》读取当日时间格式：n5",n5) #当日时间格式：yyyy-mm-dd:...

n8="20180201"#开始时间
print ("《设定测试》手动设定选股开始时间格式：n8",n8)

n9="20180209"#结束时间
print ("《设定测试》手动设定选股结束时间格式：n9",n9)

def getYesterday(): 
    today=datetime.date.today() 
    oneday=datetime.timedelta(days=200) 
    yesterday=today-oneday  
    return yesterday
n10 = (getYesterday())# 输出前200天日期
#n10="20170101"#设定起始时间
print ("《设定测试》自动设定数据起始设定前推200天：n10",n10)

x1="000001.XSHG" #用rqalpha本地数据需要代码后缀！！！！XSHE=深圳，XSHG=上海
print ("《设定测试》设定股票代码",x1)

from funcat.data.tushare_backend import TushareDataBackend
from funcat.data.rqalpha_data_backend import RQAlphaDataBackend
backend = "rqalpha"  #设定数据库连接：rqalpha   tushare
if backend == "rqalpha":
    set_data_backend(RQAlphaDataBackend())
elif backend == "tushare":
    set_data_backend(TushareDataBackend())
set_start_date(n10)

S(x1)  # 设置当前关注股票
T(n3)   # 设置当前观察日期

print ("《数据测试》打印 开盘 最高 最低 收盘 成交量",O, H, L, C, V)  # 打印 Open High Low Close
print ("《数据测试》当天涨幅",C / C[1] - 1)  # 当天涨幅
print ("《数据测试》打印60日均线",MA(C, 60))  # 打印60日均线
print ("《数据测试》判断收盘价是否大于60日均线",C > MA(C, 60))  # 判断收盘价是否大于60日均线
print ("《数据测试》30日最高价",HHV(H, 30))  # 30日最高价
print ("《数据测试》最近30日，收盘价 Close 大于60日均线的天数",COUNT(C > MA(C, 60), 30))  # 最近30日，收盘价 Close 大于60日均线的天数
print ("《数据测试》10日均线上穿",CROSS(MA(C, 10), MA(C, 20)))  # 10日均线上穿
print ("《数据测试》最近10天收阳线的天数",COUNT(C > O, 10))  # 最近10天收阳线的天数
print ("《数据测试》最近60天K线实体的最高价",HHV(MAX(O, C), 60))  # 最近60天K线实体的最高价
print ("《数据测试》5日均线上穿10日均线",CROSS(MA(C, 5), MA(C, 10)))  # 5日均线上穿10日均线

#CCI指标 方差函数模块


def AVEDEV(value,N):
    mean = value/N
    for i in range(1,N):
        mean += REF(value,i)/N
    sum_ = ABS(value-mean)
    for i in range(1,N):
        sum_ += ABS(REF(value,i)-mean)
    return sum_/N

print ("《RQALPHA本地化开始CCI选股》读取开始时间：==》n5",n5) 
# 选股CCI  OK!!!


select(
    lambda : CROSS(((((H+L+C)/3)-MA(((H+L+C)/3),14))/(0.015*AVEDEV(((H+L+C)/3),14))) or ((((((((H+L+C)/3)-MA(((H+L+C)/3),14))/(0.015*AVEDEV(((H+L+C)/3),14)))+((V-MA(V,14))/(0.015*AVEDEV(V,14))))-MA((((((H+L+C)/3)-MA(((H+L+C)/3),14))/(0.015*AVEDEV(((H+L+C)/3),14)))+((V-MA(V,14))/(0.015*AVEDEV(V,14)))),14))/(0.015*AVEDEV((((((H+L+C)/3)-MA(((H+L+C)/3),14))/(0.015*AVEDEV(((H+L+C)/3),14)))+((V-MA(V,14))/(0.015*AVEDEV(V,14)))),14))))

,101 or -101),
    start_date=(n3), end_date=(n2),)

print ("《结束选股》读取结束时间：==》n5",n5)
# Out:
# 《设定测试》读取当日时间格式：n1 2018-11-22
# 《设定测试》读取当日时间格式：n2 20181122
# 《设定测试》读取前二日时间格式：n3 2018-11-21
# 《设定测试》读取当日时间格式：n4 20181122
# 《设定测试》读取当日时间格式：n5 2018-11-22T22:20:29.546474
# 《设定测试》手动设定选股开始时间格式：n8 20180201
# 《设定测试》手动设定选股结束时间格式：n9 20180209
# 《设定测试》自动设定数据起始设定前推200天：n10 2018-05-06
# 《设定测试》设定股票代码 000001.XSHG
# 《数据测试》打印 开盘 最高 最低 收盘 成交量 2619.82 2653.8 2617.78 2651.51 18259644700.0
# 《数据测试》当天涨幅 0.002139199123155189
# 《数据测试》打印60日均线 2671.3789999999967
# 《数据测试》判断收盘价是否大于60日均线 False
# 《数据测试》30日最高价 2703.51
# 《数据测试》最近30日，收盘价 Close 大于60日均线的天数 2
# 《数据测试》10日均线上穿 False
# 《数据测试》最近10天收阳线的天数 6
# 《数据测试》最近60天K线实体的最高价 2821.35
# 《数据测试》5日均线上穿10日均线 False
# 《RQALPHA本地化开始CCI选股》读取开始时间：==》n5 2018-11-22T22:20:29.546474
# lambda : CROSS(((((H+L+C)/3)-MA(((H+L+C)/3),14))/(0.015*AVEDEV(((H+L+C)/3),14))) or ((((((((H+L+C)/3)-MA(((H+L+C)/3),14))/(0.015*AVEDEV(((H+L+C)/3),14)))+((V-MA(V,14))/(0.015*AVEDEV(V,14))))-MA((((((H+L+C)/3)-MA(((H+L+C)/3),14))/(0.015*AVEDEV(((H+L+C)/3),14)))+((V-MA(V,14))/(0.015*AVEDEV(V,14)))),14))/(0.015*AVEDEV((((((H+L+C)/3)-MA(((H+L+C)/3),14))/(0.015*AVEDEV(((H+L+C)/3),14)))+((V-MA(V,14))/(0.015*AVEDEV(V,14)))),14))))
#
# ,101 or -101),
# [20181122]
# No data for 000003.XSHE
# No data for 000013.XSHE
# No data for 000015.XSHE
# 20181122 000038.XSHE 深大通
# No data for 000047.XSHE
# 20181122 000078.XSHE 海王生物
# 20181122 000096.XSHE 广聚能源
# No data for 000405.XSHE
# No data for 000412.XSHE
# 20181122 000506.XSHE 中润资源
# No data for 000508.XSHE
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/rqalpha/data/daybar_store.py in get_bars(self, order_book_id, fields)
#      38         try:
# ---> 39             s, e = self._index[order_book_id]
#      40         except KeyError:
#
# KeyError: '000508.XSHE'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-58be2a01a182> in <module>()
#     101
#     102 ,101 or -101),
# --> 103     start_date=(n3), end_date=(n2),)
#     104
#     105 print ("《结束选股》读取结束时间：==》n5",n5)
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/funcat/helper.py in wrapper(*args, **kwargs)
#      15         try:
#      16             old_settings = np.seterr(all='ignore')
# ---> 17             return func(*args, **kwargs)
#      18         finally:
#      19             np.seterr(**old_settings)  # reset to default
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/funcat/helper.py in select(func, start_date, end_date, callback)
#      49
#      50         for order_book_id in order_book_id_list:
# ---> 51             choose(order_book_id, func, callback)
#      52
#      53     print("")
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/funcat/helper.py in choose(order_book_id, func, callback)
#      24     set_current_security(order_book_id)
#      25     try:
# ---> 26         if func():
#      27             date = ExecutionContext.get_current_date()
#      28             callback(date, order_book_id, symbol(order_book_id))
#
# <ipython-input-3-58be2a01a182> in <lambda>()
#      98
#      99 select(
# --> 100     lambda : CROSS(((((H+L+C)/3)-MA(((H+L+C)/3),14))/(0.015*AVEDEV(((H+L+C)/3),14))) or ((((((((H+L+C)/3)-MA(((H+L+C)/3),14))/(0.015*AVEDEV(((H+L+C)/3),14)))+((V-MA(V,14))/(0.015*AVEDEV(V,14))))-MA((((((H+L+C)/3)-MA(((H+L+C)/3),14))/(0.015*AVEDEV(((H+L+C)/3),14)))+((V-MA(V,14))/(0.015*AVEDEV(V,14)))),14))/(0.015*AVEDEV((((((H+L+C)/3)-MA(((H+L+C)/3),14))/(0.015*AVEDEV(((H+L+C)/3),14)))+((V-MA(V,14))/(0.015*AVEDEV(V,14)))),14))))
#     101
#     102 ,101 or -101),
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/funcat/utils.py in wrapper(*args, **kwargs)
#      24         try:
#      25             # print(func, args, kwargs)
# ---> 26             return func(*args, **kwargs)
#      27         except (ValueError, IndexError) as e:
#      28             raise FormulaException(e)
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/funcat/time_series.py in __add__(self, other)
#     140     @wrap_formula_exc
#     141     def __add__(self, other):
# --> 142         s1, s2 = fit_series(self.series, get_series(other))
#     143         with np.errstate(invalid='ignore'):
#     144             series = s1 + s2
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/funcat/time_series.py in series(self)
#     270     @property
#     271     def series(self):
# --> 272         self._ensure_series_update()
#     273         return super(MarketDataSeries, self).series
#     274
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/funcat/time_series.py in _ensure_series_update(self)
#     246             # TODO: cache
#     247             freq = self._freq if self._freq is not None else ExecutionContext.get_current_freq()
# --> 248             bars = get_bars(freq)
#     249             if len(bars) > 0:
#     250                 self._series = bars[self.name].astype(self.dtype)
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/funcat/time_series.py in get_bars(freq)
#      18
#      19     try:
# ---> 20         bars = data_backend.get_price(order_book_id, start=start_date, end=current_date, freq=freq)
#      21     except KeyError:
#      22         return np.array([])
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/funcat/data/rqalpha_data_backend.py in get_price(self, order_book_id, start, end, freq)
#      54         bars = self.data_proxy.history_bars(
#      55             order_book_id, bar_count, freq, field=None,
# ---> 56             dt=datetime.datetime.combine(end, datetime.time(23, 59, 59)))
#      57
#      58         if bars is None or len(bars) == 0:
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/rqalpha/data/data_proxy.py in history_bars(self, order_book_id, bar_count, frequency, field, dt, skip_suspended, include_now, adjust_type, adjust_orig)
#     154         return self._data_source.history_bars(instrument, bar_count, frequency, field, dt,
#     155                                               skip_suspended=skip_suspended, include_now=include_now,
# --> 156                                               adjust_type=adjust_type, adjust_orig=adjust_orig)
#     157
#     158     def current_snapshot(self, order_book_id, frequency, dt):
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/rqalpha/data/base_data_source.py in history_bars(self, instrument, bar_count, frequency, fields, dt, skip_suspended, include_now, adjust_type, adjust_orig)
#     160
#     161         if skip_suspended and instrument.type == 'CS':
# --> 162             bars = self._filtered_day_bars(instrument)
#     163         else:
#     164             bars = self._all_day_bars_of(instrument)
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/rqalpha/data/base_data_source.py in _filtered_day_bars(self, instrument)
#     114     @lru_cache(None)
#     115     def _filtered_day_bars(self, instrument):
# --> 116         bars = self._all_day_bars_of(instrument)
#     117         if bars is None:
#     118             return None
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/rqalpha/data/base_data_source.py in _all_day_bars_of(self, instrument)
#     110     def _all_day_bars_of(self, instrument):
#     111         i = self._index_of(instrument)
# --> 112         return self._day_bars[i].get_bars(instrument.order_book_id, fields=None)
#     113
#     114     @lru_cache(None)
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/rqalpha/data/daybar_store.py in get_bars(self, order_book_id, fields)
#      39             s, e = self._index[order_book_id]
#      40         except KeyError:
# ---> 41             six.print_(_(u"No data for {}").format(order_book_id))
#      42             return
#      43
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/colorama/ansitowin32.py in write(self, text)
#      38
#      39     def write(self, text):
# ---> 40         self.__convertor.write(text)
#      41
#      42
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/colorama/ansitowin32.py in write(self, text)
#     139     def write(self, text):
#     140         if self.strip or self.convert:
# --> 141             self.write_and_convert(text)
#     142         else:
#     143             self.wrapped.write(text)
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/colorama/ansitowin32.py in write_and_convert(self, text)
#     167             self.convert_ansi(*match.groups())
#     168             cursor = end
# --> 169         self.write_plain_text(text, cursor, len(text))
#     170
#     171
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/colorama/ansitowin32.py in write_plain_text(self, text, start, end)
#     172     def write_plain_text(self, text, start, end):
#     173         if start < end:
# --> 174             self.wrapped.write(text[start:end])
#     175             self.wrapped.flush()
#     176
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/colorama/ansitowin32.py in write(self, text)
#      38
#      39     def write(self, text):
# ---> 40         self.__convertor.write(text)
#      41
#      42
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/colorama/ansitowin32.py in write(self, text)
#     139     def write(self, text):
#     140         if self.strip or self.convert:
# --> 141             self.write_and_convert(text)
#     142         else:
#     143             self.wrapped.write(text)
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/colorama/ansitowin32.py in write_and_convert(self, text)
#     167             self.convert_ansi(*match.groups())
#     168             cursor = end
# --> 169         self.write_plain_text(text, cursor, len(text))
#     170
#     171
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/colorama/ansitowin32.py in write_plain_text(self, text, start, end)
#     172     def write_plain_text(self, text, start, end):
#     173         if start < end:
# --> 174             self.wrapped.write(text[start:end])
#     175             self.wrapped.flush()
#     176
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/colorama/ansitowin32.py in write(self, text)
#      38
#      39     def write(self, text):
# ---> 40         self.__convertor.write(text)
#      41
#      42
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/colorama/ansitowin32.py in write(self, text)
#     139     def write(self, text):
#     140         if self.strip or self.convert:
# --> 141             self.write_and_convert(text)
#     142         else:
#     143             self.wrapped.write(text)
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/colorama/ansitowin32.py in write_and_convert(self, text)
#     167             self.convert_ansi(*match.groups())
#     168             cursor = end
# --> 169         self.write_plain_text(text, cursor, len(text))
#     170
#     171
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/colorama/ansitowin32.py in write_plain_text(self, text, start, end)
#     173         if start < end:
#     174             self.wrapped.write(text[start:end])
# --> 175             self.wrapped.flush()
#     176
#     177
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/ipykernel/iostream.py in flush(self)
#     314         send will happen in the background thread
#     315         """
# --> 316         if self.pub_thread.thread.is_alive():
#     317             # wait for flush to actually get through:
#     318             self.pub_thread.schedule(self._flush)
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Frameworks/python/3.6.5/lib/python3.6/threading.py in is_alive(self)
#    1102         return self._ident
#    1103
# -> 1104     def is_alive(self):
#    1105         """Return whether the thread is alive.
#    1106
#
# KeyboardInterrupt:
