# %%
from matplotlib import rcParams
import matplotlib.pyplot as plt
import numpy as np

np.seterr(all='ignore')
rcParams['figure.figsize'] = (14, 6)

#扩展MOD
from funcat import * #FUNCAT的同花顺/通达信指标模块：和：&，或：|，其他基本相同。可以使用指标选股！！！
#from pytdx import * #通达信数据更新模块到QUANTAXIS的mongoDB
#from tushare import * #TUSHARE数据连接更新。
#from rqalpha import * #RQALPHA本地数据连接，通过 rqalpha update_bundle 8点后更新全部数据库
#from jaqs import * #QunatOS的jaqs客户端在线。
#from abupy import * #ABUPY本地化，数据在线下载更新，数据在线下载在根目录abu下
#from quantaxis import * #加载QUANTAXIS数据库模块，首先需要开启mongoDB+web服务器，数据更新通过通达信服务器。
#from hikyuu import * #HIKYUU本地化，数据库在根目录的stock。通过通达信导入。

#读取/设定数据库时间区域，当前股票，选股时间段。 
import time
import datetime
n1 = (time.strftime("20%y-%m-%d"))## 20yy-mm-dd格式，输出当日日期
print ("读取当日时间格式n1",n1) #当日时间格式：yyyy-mm-dd
n2 = (time.strftime("20%y%m%d"))## 20yymmdd格式，输出当日日期
print ("读取当日时间格式n2",n2) #当日时间格式：yyyymmdd
def getYesterday(): 
    today=datetime.date.today() 
    oneday=datetime.timedelta(days=1) 
    yesterday=today-oneday  
    return yesterday
n3 = (getYesterday())# 输出前一天日期
print ("读取前一日时间格式n3",n3) #前日时间格式：yyyy-mm-dd
i = datetime.datetime.now()#当前日期
n4 = ("%s%s%s" % (i.year, i.month, i.day) )
print ("读取当日时间格式n4",n4) #当日时间格式：yyyymmdd
n5 = ("%s" % i.isoformat() )
print ("读取当日时间格式n5",n5) #当日时间格式：yyyy-mm-dd:...
n8="20180101"#开始时间
print ("手动设定选股开始时间格式n8",n8)
n9="20180202"#结束时间
print ("手动设定选股结束时间格式n9",n9)
n10="20170101"#设定起始时间
print ("手动设定数据更新设定起始时间格式n10",n10)
x1="000001.XSHG"
print ("设定股票代码",x1)

#设定数据库连接：RQALPHA/TUSHARE
#from funcat.data.tushare_backend import TushareDataBackend
from funcat.data.rqalpha_data_backend import RQAlphaDataBackend
backend = "rqalpha"
if backend == "rqalpha":
    set_data_backend(RQAlphaDataBackend("~/.rqalpha/bundle"))
elif backend == "tushare":
    set_data_backend(TushareDataBackend())
set_start_date(n10)

#当前股票最新数据显示。
S(x1)  # 设置当前关注股票
T(n9)   # 设置当前观察日期

print ("打印 开盘 最高 最低 收盘 成交量",O, H, L, C, V)  # 打印 Open High Low Close
print ("当天涨幅",C / C[1] - 1)  # 当天涨幅
print ("打印60日均线",MA(C, 60))  # 打印60日均线
print ("判断收盘价是否大于60日均线",C > MA(C, 60))  # 判断收盘价是否大于60日均线
print ("30日最高价",HHV(H, 30))  # 30日最高价
print ("最近30日，收盘价 Close 大于60日均线的天数",COUNT(C > MA(C, 60), 30))  # 最近30日，收盘价 Close 大于60日均线的天数
print ("10日均线上穿",CROSS(MA(C, 10), MA(C, 20)))  # 10日均线上穿
print ("最近10天收阳线的天数",COUNT(C > O, 10))  # 最近10天收阳线的天数
print ("最近60天K线实体的最高价",HHV(MAX(O, C), 60))  # 最近60天K线实体的最高价
print ("5日均线上穿10日均线",CROSS(MA(C, 5), MA(C, 10)))  # 5日均线上穿10日均线
# Out:
# 读取当日时间格式n1 2018-02-04
# 读取当日时间格式n2 20180204
# 读取前一日时间格式n3 2018-02-03
# 读取当日时间格式n4 201824
# 读取当日时间格式n5 2018-02-04T14:44:41.573843
# 手动设定选股开始时间格式n8 20180101
# 手动设定选股结束时间格式n9 20180202
# 手动设定数据更新设定起始时间格式n10 20170101
# 设定股票代码 000001.XSHG
# 打印 开盘 最高 最低 收盘 成交量 3419.22 3463.16 3388.86 3462.08 20812055100.0
# 当天涨幅 0.004380646246859632
# 打印60日均线 3381.247499999997
# 判断收盘价是否大于60日均线 True
# 30日最高价 3587.03
# 最近30日，收盘价 Close 大于60日均线的天数 23
# 10日均线上穿 False
# 最近10天收阳线的天数 6
# 最近60天K线实体的最高价 3563.64
# 5日均线上穿10日均线 False

# %%
#当前股票价格均线+买卖
ax = plt.subplot()

#buy_signal = CROSS(ma1, ma7)
#sell_signal = CROSS(ma7, ma1)
plt.plot(C.series, label="H", linewidth=1,color="red")
plt.plot(MA(L,1).series, label="ma1", alpha=0.7)
plt.plot(MA(H,3).series, label="ma2", alpha=0.7)
plt.plot(MA(H,5).series, label="ma3", alpha=0.7)
plt.plot(MA(H,7).series, label="ma4", alpha=0.7)
#plt.plot(MA(H,11).series, label="ma5", alpha=0.7)
#plt.plot(MA(H,22).series, label="ma6", alpha=0.7)
#plt.plot(MA(H,66).series, label="ma7", alpha=0.7)
ax.set_xlim(0)
#plt.plot(np.where(buy_signal.series)[0], C.series[np.where(buy_signal.series)[0]], "^", label="buy", markersize=12, color="red")
#plt.plot(np.where(sell_signal.series)[0], C.series[np.where(sell_signal.series)[0]], "v", label="sell", markersize=12, color="green")
plt.legend(loc="best")
plt.show()

#当前股票价格均线+KDJ显示图及买卖
RSV = (HHV(H,1)-LLV(L,27))/(HHV(H,27)-LLV(L,27))*100
K = EMA(RSV, (9 * 2 - 1))
D = EMA(K, (3 * 2 - 1))
J = K * 3 - D * 2
print(K, D, J)
f, (ax1, ax2,) = plt.subplots(2, 1)
ax1.plot(H.series, label="H", linewidth=1,color="red")
#ax1.plot(MA(V, 7).series, label="ma7", alpha=0.7)
#ax1.plot(MA(V, 11).series, label="ma11", alpha=0.7)
#ax1.plot(MA(V, 22).series, label="ma22", alpha=0.7)
#ax1.plot(MA(V, 66).series, label="ma66", alpha=0.7)
ax1.set_xlim(0)
ax2.plot(K.series, label="K", linewidth=1)
ax2.plot(D.series, label="D", alpha=0.7)
ax2.plot(J.series, label="J", alpha=0.7)
ax2.set_xlim(0)
#buy_signal = CROSS(J, K)
#sell_signal = CROSS(K, J)
buy_signal = (CROSS(IF(D<50,J,D),D) and CROSS(IF(D<50,K,J),D)) #CROSS(J, K)
sell_signal = (CROSS(D,IF(D>80,J,D)) and CROSS(D,IF(D>80,K,J))) #CROSS(K, J)

plt.plot(np.where(buy_signal.series)[0], K.series[np.where(buy_signal.series)[0]], "^", label="buy", markersize=12, color="red")
plt.plot(np.where(sell_signal.series)[0], J.series[np.where(sell_signal.series)[0]], "v", label="sell", markersize=12, color="green")
plt.legend(loc="best")
plt.show()


#当前股票成交量均线+DMA指标+买卖
#又叫平行线差指标，是目前股市分析技术指标中的一种中短期指标，它常用于大盘指数和个股的研判。

DDD = MA(CLOSE, 10) - MA(CLOSE, 50)
AMA = MA(DDD, 10)
print(DDD, AMA)
f, (ax1, ax2) = plt.subplots(2, 1)
ax1.plot(V.series, label="V", linewidth=1,color="red")
ax1.plot(MA(V, 7).series, label="ma1", alpha=0.7)
ax1.plot(MA(V, 11).series, label="ma2", alpha=0.7)
ax1.plot(MA(V, 22).series, label="ma3", alpha=0.7)
ax1.plot(MA(V, 66).series, label="ma4", alpha=0.7)
ax1.set_xlim(0)
ax2.plot(DDD.series, label="DDD", linewidth=1)
ax2.plot(AMA.series, label="AMA", linewidth=1)
ax2.set_xlim(0)
#buy_signal = CROSS(DDD, AMA)
#sell_signal = CROSS(AMA, DDD)
buy_signal = CROSS(IF(DDD<-10,DDD,AMA),AMA) 
sell_signal = CROSS(AMA, DDD)#CROSS(IF(DDD>70,DDD,DDD),DDD) 

plt.plot(np.where(buy_signal.series)[0], AMA.series[np.where(buy_signal.series)[0]], "^", label="buy", markersize=12, color="red")
plt.plot(np.where(sell_signal.series)[0], DDD.series[np.where(sell_signal.series)[0]], "v", label="sell", markersize=12, color="green")
plt.legend(loc="best")
plt.show()

#CCI指标 方差函数模块
def AVEDEV(value,N):
    mean = value/N
    for i in range(1,N):
        mean += REF(value,i)/N
    sum_ = ABS(value-mean)
    for i in range(1,N):
        sum_ += ABS(REF(value,i)-mean)
    
    return sum_/N
#M=14
TYP = (H+L+C)/3
CCI = (TYP-MA(TYP,14))/(0.015*AVEDEV(TYP,14))
VCCI = (V-MA(V,14))/(0.015*AVEDEV(V,14))
VC = ((CCI+VCCI)-MA((CCI+VCCI),14))/(0.015*AVEDEV((CCI+VCCI),14))
VV= VC+CCI
print (VCCI,CCI,VC)
f, (ax1,ax2) = plt.subplots(2,1)
ax1.plot(L.series, label="L", linewidth=1,color="red")
#ax1.plot(MA(L, 7).series, label="ma7", alpha=0.7)
#ax1.plot(MA(H, 11).series, label="ma11", alpha=0.7)
#ax1.plot(MA(H, 22).series, label="ma22", alpha=0.7)
#ax1.plot(MA(H, 66).series, label="ma66", alpha=0.7)
ax1.set_xlim(0)
ax2.plot(VC.series, label="VC",linewidth=1,color="red")
ax2.plot(MA(VC,3).series, label="vcci1", alpha=0.7)
ax2.plot(MA(VC, 4).series, label="vcci2", alpha=0.7)
ax2.plot(MA(VC, 5).series, label="vcci3", alpha=0.7)
ax2.plot(MA(VC, 6).series, label="vcci4", alpha=0.7)
ax2.plot(CCI.series, label="CCI",linewidth=1, color="green")
ax2.plot(MA(CCI, 3).series, label="cci1", alpha=0.7)
ax2.plot(MA(CCI, 4).series, label="cci2", alpha=0.7)
ax2.plot(MA(CCI, 5).series, label="cci3", alpha=0.7)
ax2.plot(MA(CCI, 6).series, label="cci4", alpha=0.7)
ax2.set_xlim(-14)
N1=101
N2=-101
N3=101
buy_signal = CROSS(CCI or VC,N1 or N2)
sell_signal = CROSS(CCI+VC,N1+N2)
plt.plot(np.where(buy_signal.series)[0], CCI.series[np.where(buy_signal.series)[0]], "^", label="buy", markersize=12, color="red")
#plt.plot(np.where(sell_signal.series)[0], CCI.series[np.where(sell_signal.series)[0]], "v", label="sell", markersize=12, color="green")
plt.legend(loc="best")
plt.show()
# Out:
# 84.49780227203001 87.74779158857099 77.99782363894806
# 135.5704000000037 124.5776200000029
# -74.96476964046275 -99.39396130027039 -173.7574668858297

# %%
# 选股CCI  OK!!!
select(
    lambda : CROSS(((((H+L+C)/3)-MA(((H+L+C)/3),14))/(0.015*AVEDEV(((H+L+C)/3),14))) or ((((((((H+L+C)/3)-MA(((H+L+C)/3),14))/(0.015*AVEDEV(((H+L+C)/3),14)))+((V-MA(V,14))/(0.015*AVEDEV(V,14))))-MA((((((H+L+C)/3)-MA(((H+L+C)/3),14))/(0.015*AVEDEV(((H+L+C)/3),14)))+((V-MA(V,14))/(0.015*AVEDEV(V,14)))),14))/(0.015*AVEDEV((((((H+L+C)/3)-MA(((H+L+C)/3),14))/(0.015*AVEDEV(((H+L+C)/3),14)))+((V-MA(V,14))/(0.015*AVEDEV(V,14)))),14))))

,101 or -101),start_date=(n8),end_date=(n9),)
# Out:
# lambda : CROSS(((((H+L+C)/3)-MA(((H+L+C)/3),14))/(0.015*AVEDEV(((H+L+C)/3),14))) or ((((((((H+L+C)/3)-MA(((H+L+C)/3),14))/(0.015*AVEDEV(((H+L+C)/3),14)))+((V-MA(V,14))/(0.015*AVEDEV(V,14))))-MA((((((H+L+C)/3)-MA(((H+L+C)/3),14))/(0.015*AVEDEV(((H+L+C)/3),14)))+((V-MA(V,14))/(0.015*AVEDEV(V,14)))),14))/(0.015*AVEDEV((((((H+L+C)/3)-MA(((H+L+C)/3),14))/(0.015*AVEDEV(((H+L+C)/3),14)))+((V-MA(V,14))/(0.015*AVEDEV(V,14)))),14))))
#
# ,101 or -101),start_date=(n8),end_date=(n9),)
# [20180122]
# 20180122 000055.XSHE 方大集团
# 20180122 000417.XSHE 合肥百货
# 20180122 000532.XSHE 华金资本
# 20180122 000539.XSHE 粤电力A
# 20180122 000572.XSHE 海马汽车
# 20180122 000596.XSHE 古井贡酒
# 20180122 000651.XSHE 格力电器
# 20180122 000661.XSHE 长春高新
# 20180122 000665.XSHE 湖北广电
# 20180122 000736.XSHE 中交地产
# 20180122 000801.XSHE 四川九洲
# 20180122 000833.XSHE 贵糖股份
# 20180122 000932.XSHE *ST华菱
# 20180122 000955.XSHE 欣龙控股
# 20180122 000960.XSHE 锡业股份
# 20180122 000982.XSHE *ST中绒
# 20180122 000999.XSHE 华润三九
# 20180122 001896.XSHE 豫能控股
# 20180122 002022.XSHE 科华生物
# 20180122 002027.XSHE 分众传媒
# 20180122 002044.XSHE 美年健康
# 20180122 002054.XSHE 德美化工
# 20180122 002094.XSHE 青岛金王
# 20180122 002095.XSHE 生意宝
# 20180122 002110.XSHE 三钢闽光
# 20180122 002124.XSHE 天邦股份
# 20180122 002183.XSHE 怡亚通
# 20180122 002207.XSHE *ST准油
# 20180122 002315.XSHE 焦点科技
# 20180122 002336.XSHE 人人乐
# 20180122 002356.XSHE 赫美集团
# 20180122 002359.XSHE 北讯集团
# 20180122 002388.XSHE 新亚制程
# 20180122 002399.XSHE 海普瑞
# 20180122 002408.XSHE 齐翔腾达
# 20180122 002428.XSHE 云南锗业
# 20180122 002513.XSHE 蓝丰生化
# 20180122 002550.XSHE 千红制药
# 20180122 002559.XSHE 亚威股份
# 20180122 002602.XSHE 世纪华通
# 20180122 002628.XSHE 成都路桥
# 20180122 002630.XSHE 华西能源
# 20180122 002698.XSHE 博实股份
# 20180122 002707.XSHE 众信旅游
# 20180122 002727.XSHE 一心堂
# 20180122 002735.XSHE 王子新材
# 20180122 002742.XSHE 三圣股份
# 20180122 002755.XSHE 东方新星
# 20180122 002795.XSHE 永和智控
# 20180122 002817.XSHE 黄山胶囊
# 20180122 002836.XSHE 新宏泽
# 20180122 002847.XSHE 盐津铺子
# 20180122 002868.XSHE 绿康生化
# 20180122 002876.XSHE 三利谱
# No data for 002926.XSHE
# 20180122 300005.XSHE 探路者
# 20180122 300023.XSHE 宝德股份
# 20180122 300039.XSHE 上海凯宝
# 20180122 300050.XSHE 世纪鼎利
# 20180122 300053.XSHE 欧比特
# 20180122 300082.XSHE 奥克股份
# 20180122 300157.XSHE 恒泰艾普
# 20180122 300162.XSHE 雷曼股份
# 20180122 300205.XSHE 天喻信息
# 20180122 300222.XSHE 科大智能
# 20180122 300227.XSHE 光韵达
# 20180122 300239.XSHE 东宝生物
# 20180122 300256.XSHE 星星科技
# 20180122 300269.XSHE 联建光电
# 20180122 300275.XSHE 梅安森
# 20180122 300276.XSHE 三丰智能
# 20180122 300282.XSHE 汇冠股份
# 20180122 300324.XSHE 旋极信息
# 20180122 300369.XSHE 绿盟科技
# 20180122 300380.XSHE 安硕信息
# 20180122 300416.XSHE 苏试试验
# 20180122 300451.XSHE 创业软件
# 20180122 300461.XSHE 田中精机
# 20180122 300491.XSHE 通合科技
# 20180122 300495.XSHE 美尚生态
# 20180122 300514.XSHE 友讯达
# 20180122 300534.XSHE 陇神戎发
# 20180122 300539.XSHE 横河模具
# 20180122 300559.XSHE 佳发安泰
# 20180122 300595.XSHE 欧普康视
# 20180122 300629.XSHE 新劲刚
# 20180122 300685.XSHE 艾德生物
# 20180122 600022.XSHG 山东钢铁
# 20180122 600023.XSHG 浙能电力
# 20180122 600096.XSHG 云天化
# 20180122 600105.XSHG 永鼎股份
# 20180122 600121.XSHG *ST郑煤
# 20180122 600126.XSHG 杭钢股份
# 20180122 600138.XSHG 中青旅
# 20180122 600167.XSHG 联美控股
# 20180122 600180.XSHG 瑞茂通
# 20180122 600189.XSHG 吉林森工
# 20180122 600191.XSHG 华资实业
# 20180122 600199.XSHG 金种子酒
# 20180122 600234.XSHG ST山水
# 20180122 600282.XSHG 南钢股份
# 20180122 600310.XSHG 桂东电力
# 20180122 600395.XSHG 盘江股份
# 20180122 600436.XSHG 片仔癀
# 20180122 600479.XSHG 千金药业
# 20180122 600491.XSHG 龙元建设
# 20180122 600546.XSHG 山煤国际
# 20180122 600551.XSHG 时代出版
# 20180122 600612.XSHG 老凤祥
# 20180122 600642.XSHG 申能股份
# 20180122 600682.XSHG 南京新百
# 20180122 600702.XSHG 舍得酒业
# 20180122 600707.XSHG 彩虹股份
# 20180122 600723.XSHG 首商股份
# 20180122 600757.XSHG 长江传媒
# 20180122 600763.XSHG 通策医疗
# 20180122 600764.XSHG 中国海防
# 20180122 600782.XSHG 新钢股份
# 20180122 600808.XSHG 马钢股份
# 20180122 600819.XSHG 耀皮玻璃
# 20180122 600892.XSHG 大晟文化
# 20180122 600977.XSHG 中国电影
# 20180122 601001.XSHG 大同煤业
# 20180122 601006.XSHG 大秦铁路
# 20180122 601225.XSHG 陕西煤业
# 20180122 601518.XSHG 吉林高速
# 20180122 601888.XSHG 中国国旅
# 20180122 603009.XSHG 北特科技
# 20180122 603077.XSHG 和邦生物
# 20180122 603345.XSHG 安井食品
# 20180122 603505.XSHG 金石资源
# 20180122 603568.XSHG 伟明环保
# 20180122 603605.XSHG 珀莱雅
# 20180122 603661.XSHG 恒林股份
# 20180122 603707.XSHG 健友股份
# 20180122 603726.XSHG 朗迪集团
# 20180122 603729.XSHG 龙韵股份
# 20180122 603766.XSHG 隆鑫通用
# 20180122 603826.XSHG 坤彩科技
# 20180122 603909.XSHG 合诚股份
# 20180122 603993.XSHG 洛阳钼业

# %%
# KDJ选股 ok！！！
select(
    lambda : CROSS((EMA(((C-LLV(L,27))/(HHV(H,27)-LLV(L,27))*100),(M1*2-1)))*3-(EMA(EMA(((C-LLV(L,27))/(HHV(H,27)-LLV(L,27))*100),(M1*2-1)),(M2*2-1)))*2,(EMA(((C-LLV(L,27))/(HHV(H,27)-LLV(L,27))*100),(M1*2-1))))

,
    start_date=(n8),
	end_date=(n9),
)
# Out:
# lambda : CROSS((EMA(((CLOSE - LLV(LOW, 27)) / (HHV(HIGH, 27) - LLV(LOW, 27)) * 100), (M1 * 2 - 1))) * 3 - (EMA(EMA(((CLOSE - LLV(LOW, 27)) / (HHV(HIGH, 27) - LLV(LOW, 27)) * 100), (M1 * 2 - 1)), (M2 * 2 - 1))) * 2, (EMA(((CLOSE - LLV(LOW, 27)) / (HHV(HIGH, 27) - LLV(LOW, 27)) * 100), (M1 * 2 - 1))))
# [20180122]
# 20180122 000532.XSHE 华金资本
# 20180122 000536.XSHE 华映科技
# 20180122 000661.XSHE 长春高新
# 20180122 000783.XSHE 长江证券
# 20180122 000987.XSHE 越秀金控
# 20180122 002032.XSHE 苏泊尔
# 20180122 002243.XSHE 通产丽星
# 20180122 002361.XSHE 神剑股份
# 20180122 002441.XSHE 众业达
# 20180122 002519.XSHE 银河电子
# 20180122 002634.XSHE 棒杰股份
# 20180122 002707.XSHE 众信旅游
# 20180122 002749.XSHE 国光股份
# 20180122 300047.XSHE 天源迪科
# 20180122 300079.XSHE 数码科技
# 20180122 300099.XSHE 精准信息
# 20180122 300269.XSHE 联建光电
# 20180122 300304.XSHE 云意电气
# 20180122 300307.XSHE 慈星股份
# 20180122 300328.XSHE 宜安科技
# 20180122 300336.XSHE 新文化
# 20180122 300358.XSHE 楚天科技
# 20180122 300380.XSHE 安硕信息
# 20180122 300477.XSHE 合纵科技
# 20180122 300501.XSHE 海顺新材
# 20180122 300514.XSHE 友讯达
# 20180122 300516.XSHE 久之洋
# 20180122 300546.XSHE 雄帝科技
# 20180122 300642.XSHE 透景生命
# 20180122 600018.XSHG 上港集团
# 20180122 600099.XSHG 林海股份
# 20180122 600109.XSHG 国金证券
# 20180122 600119.XSHG 长江投资
# 20180122 600343.XSHG 航天动力
# 20180122 600399.XSHG 抚顺特钢
# 20180122 600621.XSHG 华鑫股份
# 20180122 600671.XSHG 天目药业
# 20180122 600702.XSHG 舍得酒业
# 20180122 600787.XSHG 中储股份
# 20180122 600795.XSHG 国电电力
# 20180122 600826.XSHG 兰生股份
# 20180122 600831.XSHG 广电网络
# 20180122 600898.XSHG 国美通讯
# 20180122 601126.XSHG 四方股份
# 20180122 601318.XSHG 中国平安
# 20180122 601788.XSHG 光大证券
# 20180122 601880.XSHG 大连港
# 20180122 601928.XSHG 凤凰传媒
# 20180122 603023.XSHG 威帝股份
# 20180122 603100.XSHG 川仪股份
# 20180122 603218.XSHG 日月股份
# 20180122 603601.XSHG 再升科技
# 20180122 603888.XSHG 新华网

# %%
#当前股票成交量均线+DMA指标+买卖
#又叫平行线差指标，是目前股市分析技术指标中的一种中短期指标，它常用于大盘指数和个股的研判。
M1 = 10
M2 = 50
M3 = 10
DDD = MA(CLOSE, M1) - MA(CLOSE, M2)
AMA = MA(DDD, M3)
print (DDD,AMA)
M1 = 10
M2 = 50
M3 = 10

DDD = (MA(C,10)-MA(C, 50))
AMA = (MA((MA(C,10)-MA(C, 50)),10))




dmi=CROSS((MA(C,10)-MA(C,50)),(MA((MA(C,10)-MA(C,50)),10)))

print(DDD, AMA,dmi)

select(
    lambda : CROSS((MA(H,10)-MA(H,50)),(MA((MA(H,10)-MA(H,50)),10))),
    start_date=(n8),
	end_date=(n9),
)
# Out:
# -0.1579999999999968 -0.2411399999999954
# -0.1579999999999968 -0.2411399999999954 False
# lambda : CROSS((MA(H,10)-MA(H,50)),(MA((MA(H,10)-MA(H,50)),10))),
# [20180122]
# 20180122 000063.XSHE 中兴通讯
# 20180122 000892.XSHE 欢瑞世纪
# 20180122 002054.XSHE 德美化工
# 20180122 002090.XSHE 金智科技
# 20180122 002188.XSHE 巴士在线
# 20180122 002212.XSHE 南洋股份
# 20180122 002252.XSHE 上海莱士
# 20180122 002416.XSHE 爱施德
# 20180122 002750.XSHE 龙津药业
# 20180122 002812.XSHE 创新股份
# 20180122 300256.XSHE 星星科技
# 20180122 300337.XSHE 银邦股份
# 20180122 300360.XSHE 炬华科技
# 20180122 300601.XSHE 康泰生物
# 20180122 600088.XSHG 中视传媒
# 20180122 600196.XSHG 复星医药
# 20180122 600234.XSHG ST山水
# 20180122 600290.XSHG 华仪电气
# 20180122 600498.XSHG 烽火通信
# 20180122 600597.XSHG 光明乳业
# 20180122 600707.XSHG 彩虹股份
# 20180122 603023.XSHG 威帝股份
# 20180122 603458.XSHG 勘设股份
# 20180122 603601.XSHG 再升科技
# 20180122 603838.XSHG 四通股份

# %%
#kdj<30 cross(j<30,k)
select(
    lambda : CROSS((EMA(((C - LLV(L, 27)) / (HHV(HIGH, 27) - LLV(LOW, 27)) * 100), (M1 * 2 - 1))) * 3 - (EMA(EMA(((CLOSE - LLV(LOW, 27)) / (HHV(HIGH, 27) - LLV(LOW, 27)) * 100), (M1 * 2 - 1)), (M2 * 2 - 1))) * 2

<40,(EMA(((CLOSE - LLV(LOW, 27)) / (HHV(HIGH, 27) - LLV(LOW, 27)) * 100), (M1 * 2 - 1)))

),
    start_date=(n8),
	end_date=(n9),
)
# Out:
# lambda : CROSS((EMA(((C - LLV(L, 27)) / (HHV(HIGH, 27) - LLV(LOW, 27)) * 100), (M1 * 2 - 1))) * 3 - (EMA(EMA(((CLOSE - LLV(LOW, 27)) / (HHV(HIGH, 27) - LLV(LOW, 27)) * 100), (M1 * 2 - 1)), (M2 * 2 - 1))) * 2
#
# <40,(EMA(((CLOSE - LLV(LOW, 27)) / (HHV(HIGH, 27) - LLV(LOW, 27)) * 100), (M1 * 2 - 1)))
#
# ),
# [20180202]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-129-a4c75a02d8bb> in <module>()
#       7 ),
#       8     start_date=(n8),
# ----> 9         end_date=(n9),
#      10 )
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/funcat/helper.py in wrapper(*args, **kwargs)
#      15         try:
#      16             old_settings = np.seterr(all='ignore')
# ---> 17             return func(*args, **kwargs)
#      18         finally:
#      19             np.seterr(**old_settings)  # reset to default
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/funcat/helper.py in select(func, start_date, end_date, callback)
#      49
#      50         for order_book_id in order_book_id_list:
# ---> 51             choose(order_book_id, func, callback)
#      52
#      53     print("")
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/funcat/helper.py in choose(order_book_id, func, callback)
#      24     set_current_security(order_book_id)
#      25     try:
# ---> 26         if func():
#      27             date = ExecutionContext.get_current_date()
#      28             callback(date, order_book_id, symbol(order_book_id))
#
# <ipython-input-129-a4c75a02d8bb> in <lambda>()
#       1 #kdj<30 cross(j<30,k)
#       2 select(
# ----> 3     lambda : CROSS((EMA(((C - LLV(L, 27)) / (HHV(HIGH, 27) - LLV(LOW, 27)) * 100), (M1 * 2 - 1))) * 3 - (EMA(EMA(((CLOSE - LLV(LOW, 27)) / (HHV(HIGH, 27) - LLV(LOW, 27)) * 100), (M1 * 2 - 1)), (M2 * 2 - 1))) * 2
#       4
#       5 <40,(EMA(((CLOSE - LLV(LOW, 27)) / (HHV(HIGH, 27) - LLV(LOW, 27)) * 100), (M1 * 2 - 1)))
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/funcat/utils.py in wrapper(*args, **kwargs)
#      24         try:
#      25             # print(func, args, kwargs)
# ---> 26             return func(*args, **kwargs)
#      27         except (ValueError, IndexError) as e:
#      28             raise FormulaException(e)
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/funcat/time_series.py in __mul__(self, other)
#     154     @wrap_formula_exc
#     155     def __mul__(self, other):
# --> 156         s1, s2 = fit_series(self.series, get_series(other))
#     157         with np.errstate(invalid='ignore'):
#     158             series = s1 * s2
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/funcat/time_series.py in get_series(val)
#      52         return val.series
#      53     else:
# ---> 54         return DuplicateNumericSeries(val).series
#      55
#      56
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/funcat/time_series.py in __init__(self, series, size)
#     228         except:
#     229             val = series
# --> 230         super(DuplicateNumericSeries, self).__init__(np.full(size, val, dtype=np.float64))
#     231
#     232
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/numpy/core/numeric.py in full(shape, fill_value, dtype, order)
#     297         dtype = array(fill_value).dtype
#     298     a = empty(shape, dtype, order)
# --> 299     multiarray.copyto(a, fill_value, casting='unsafe')
#     300     return a
#     301
#
# KeyboardInterrupt:

# %%
#新指标


#def CCC(M1 =[1&2&3&5&7&9&11&13&15&17&19]):
#def CCC(M1 =[1,2,3,5,7,9,11,13,15,17,19]):
#def CCC(M1 =len([1*2*3*5*7*9*11*13*15*17*19])):
#def CCC(M1 = (list(range(1, 22)))) :
#def CCC(M1=[x * x for x in range(1, 11)]):
def CCI(M1=14):    
    CCC = (((REF(HIGH,M1) + REF(LOW,M1) + REF(CLOSE,M1)
      )/3.14159265)-MA(((REF(HIGH,M1) + REF(LOW,M1) + REF(CLOSE,M1)
        )/3.14159265),M1))/(0.618*AVEDEV(((REF(HIGH,M1) + REF(LOW,M1
         ) + REF(CLOSE,M1))/3.14159265),M1))
    return CCC
    
def AVEDEV(value,N):
    mean = value/N
    for i in range(1,N):
        mean += REF(value,i)/N
    sum_ = ABS(value-mean)
    for i in range(1,N):
        sum_ += ABS(REF(value,i)-mean)
    
    return sum_/N
    
def AVE_DEV(value,N):
    mean = value/N
    for i in range(1,N):
        mean += REF(value,i)/N
    AVE = ABS(value-mean)
    for i in range(1,N):
        AVE += ABS(REF(value,i)-mean)

    return AVE/N


select(
    lambda :
    (((REF(HIGH,14) + REF(LOW,14) + REF(CLOSE,14))/3.14159265)-MA(((REF(HIGH,14) + REF(LOW,14) + REF(CLOSE,14))
    /3.14159265),14))/(0.618*AVEDEV(((REF(HIGH,14) + REF(LOW,14) + REF(CLOSE,14))/3.14159265),14)) > 100 ,
    
    start_date=(n8),
    end_date=(n9),
)
# Out:
# lambda :
# [20180202]
# No data for 002926.XSHE
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-190-1b6f7661f046> in <module>()
#      41
#      42     start_date=(n8),
# ---> 43     end_date=(n9),
#      44 )
#      45
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/funcat/helper.py in wrapper(*args, **kwargs)
#      15         try:
#      16             old_settings = np.seterr(all='ignore')
# ---> 17             return func(*args, **kwargs)
#      18         finally:
#      19             np.seterr(**old_settings)  # reset to default
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/funcat/helper.py in select(func, start_date, end_date, callback)
#      49
#      50         for order_book_id in order_book_id_list:
# ---> 51             choose(order_book_id, func, callback)
#      52
#      53     print("")
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/funcat/helper.py in choose(order_book_id, func, callback)
#      24     set_current_security(order_book_id)
#      25     try:
# ---> 26         if func():
#      27             date = ExecutionContext.get_current_date()
#      28             callback(date, order_book_id, symbol(order_book_id))
#
# <ipython-input-190-1b6f7661f046> in <lambda>()
#      37 select(
#      38     lambda :
# ---> 39     (((REF(HIGH,14) + REF(LOW,14) + REF(CLOSE,14))/3.14159265)-MA(((REF(HIGH,14) + REF(LOW,14) + REF(CLOSE,14))
#      40     /3.14159265),14))/(0.618*AVEDEV(((REF(HIGH,14) + REF(LOW,14) + REF(CLOSE,14))/3.14159265),14)) > 100 ,
#      41
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/funcat/func.py in Ref(s1, n)
#     130
#     131 def Ref(s1, n):
# --> 132     return s1[n]
#     133
#     134
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/funcat/time_series.py in __getitem__(self, index)
#     266             return time_series
#     267
# --> 268         return self.__class__(series=self.series[:len(self.series) - index], **self.extra_create_kwargs)
#     269
#     270     @property
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/funcat/time_series.py in series(self)
#     270     @property
#     271     def series(self):
# --> 272         self._ensure_series_update()
#     273         return super(MarketDataSeries, self).series
#     274
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/funcat/time_series.py in _ensure_series_update(self)
#     246             # TODO: cache
#     247             freq = self._freq if self._freq is not None else ExecutionContext.get_current_freq()
# --> 248             bars = get_bars(freq)
#     249             if len(bars) > 0:
#     250                 self._series = bars[self.name].astype(self.dtype)
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/funcat/time_series.py in get_bars(freq)
#      18
#      19     try:
# ---> 20         bars = data_backend.get_price(order_book_id, start=start_date, end=current_date, freq=freq)
#      21     except KeyError:
#      22         return np.array([])
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/funcat/data/rqalpha_data_backend.py in get_price(self, order_book_id, start, end, freq)
#      54         bars = self.data_proxy.history_bars(
#      55             order_book_id, bar_count, freq, field=None,
# ---> 56             dt=datetime.datetime.combine(end, datetime.time(23, 59, 59)))
#      57
#      58         if bars is None or len(bars) == 0:
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/rqalpha/data/data_proxy.py in history_bars(self, order_book_id, bar_count, frequency, field, dt, skip_suspended, include_now, adjust_type, adjust_orig)
#     154         return self._data_source.history_bars(instrument, bar_count, frequency, field, dt,
#     155                                               skip_suspended=skip_suspended, include_now=include_now,
# --> 156                                               adjust_type=adjust_type, adjust_orig=adjust_orig)
#     157
#     158     def current_snapshot(self, order_book_id, frequency, dt):
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/rqalpha/data/base_data_source.py in history_bars(self, instrument, bar_count, frequency, fields, dt, skip_suspended, include_now, adjust_type, adjust_orig)
#     160
#     161         if skip_suspended and instrument.type == 'CS':
# --> 162             bars = self._filtered_day_bars(instrument)
#     163         else:
#     164             bars = self._all_day_bars_of(instrument)
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/rqalpha/data/base_data_source.py in _filtered_day_bars(self, instrument)
#     114     @lru_cache(None)
#     115     def _filtered_day_bars(self, instrument):
# --> 116         bars = self._all_day_bars_of(instrument)
#     117         if bars is None:
#     118             return None
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/rqalpha/data/base_data_source.py in _all_day_bars_of(self, instrument)
#     110     def _all_day_bars_of(self, instrument):
#     111         i = self._index_of(instrument)
# --> 112         return self._day_bars[i].get_bars(instrument.order_book_id, fields=None)
#     113
#     114     @lru_cache(None)
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/rqalpha/data/daybar_store.py in get_bars(self, order_book_id, fields)
#      57         result = np.empty(shape=(e - s, ), dtype=dtype)
#      58         for f in fields:
# ---> 59             result[f] = self._converter.convert(f, self._table.cols[f][s:e])
#      60         result['datetime'] = self._table.cols['date'][s:e]
#      61         result['datetime'] *= 1000000
#
# KeyboardInterrupt:

# %%
from pandas import Series, DataFrame
import pandas as pd

def AVEDEV(value,N):
    mean = value/N
    for i in range(1,N):
        mean += REF(value,i)/N
    sum_ = ABS(value-mean)
    for i in range(1,N):
        sum_ += ABS(REF(value,i)-mean)
    return sum_/N
def AVE_DEV(value,N):
    mean = value/N
    for i in range(1,N):
        mean += REF(value,i)/N
    AVE = ABS(value-mean)
    for i in range(1,N):
        AVE += ABS(REF(value,i)-mean)
    return AVE/N

M=2

#M1 =[1&2&3&5&7&9&11&13&15&17&19]
#M1 =[1,2,3,5,7,9,11,13,15,17,19]
#M1 =len([1*2*3*5*7*9*11*13*15*17*19])
#M1 = list(range(1, 11))
#M1 = [x * x for x in range(1, 11)]
#dM1=14
TYPI = (HIGH+LOW+CLOSE)/3
CCI = (TYPI-MA(TYPI,M))/(0.015*AVEDEV(TYPI,M))

TYP = (REF(HIGH,M)+REF(LOW,M)+REF(CLOSE,M)+REF(VOL,M))/3.14159265  
CCC = (TYP-MA(TYP,M))/(0.618*AVEDEV(TYP,M))
TYP1 = (REF(V,M)+REF(V,M)+REF(V,M)+REF(V,M))/3.14159265  
DDD = (CCC*CCC*CCC)/CCI
#CCC = (((REF(HIGH,M1) + REF(LOW,M1) + REF(CLOSE,M1))/3.14159265)-MA(((REF(HIGH,M1) + REF(LOW,M1) + REF(CLOSE,M1))/3.14159265),M1))/(0.618*AVEDEV(((REF(HIGH,M1) + REF(LOW,M1) + REF(CLOSE,M1))/3.14159265),M1))
#X = TYP-MA((V*L)/(0.015*AVEDEV((X*L),M))
print (CCI,CCC,DDD,X)
f, (ax1,ax2) = plt.subplots(2,1)
#ax = plt.subplot()
#ax2.plot(H.series, label="H",linewidth=1)
#ax1.plot(X.series, label="X",linewidth=1)
#ax2.plot(CCC.series, label="CCC",linewidth=1)
#ax2.plot(DDD.series, label="DDD",linewidth=1)
plt.legend(loc="best")
plt.show()

# %%
#CCI 指标

def CCI(M1=14):
    TYP = (HIGH+LOW+CLOSE)/3
    CCI = (TYP-MA(TYP,M1))/(0.015*AVEDEV(TYP,M1))
    return CCI
    
def AVEDEV(value,N):
    mean = value/N
    for i in range(1,N):
        mean += REF(value,i)/N
    sum_ = ABS(value-mean)
    for i in range(1,N):
        sum_ += ABS(REF(value,i)-mean)
    
    return sum_/N
'''	
def AVEDEV(value,N):
	mean = value/N
	for i in range(1,N):
		mean += REF(value,i)/N
	AVE = ABS(value-mean)
	for i in range(1,N):
	    AVE += ABS(REF(value,i)-mean)
	
	return AVE/N
'''

select(
    lambda : (((REF(HIGH,14) + REF(LOW,14) + REF(CLOSE,14))/3.14159265)-MA(((REF(HIGH,14) + REF(LOW,14) + REF(CLOSE,14))/3.14159265),14))/(0.618*AVEDEV(((REF(HIGH,14) + REF(LOW,14) + REF(CLOSE,14))/3.14159265),14)) > 100,
    start_date=(n8),
	end_date=(n9),
)
# Out:
# lambda : (((REF(HIGH,14) + REF(LOW,14) + REF(CLOSE,14))/3.14159265)-MA(((REF(HIGH,14) + REF(LOW,14) + REF(CLOSE,14))/3.14159265),14))/(0.618*AVEDEV(((REF(HIGH,14) + REF(LOW,14) + REF(CLOSE,14))/3.14159265),14)) > 100,
# [20180202]

# %%
'''
    TYP = ((REF(HIGH,M1) + REF(LOW,M1) + REF(CLOSE,M1))/3.14159265)    
    CCC1 = (TYP-MA(TYP,1))/(0.618*avedev(TYP,1))
    CCC2 = (TYP-MA(TYP,2))/(0.618*AVEDEV(TYP,2))
    CCC3 = (TYP-MA(TYP,3))/(0.618*ABS(TYP,3))
    CCC4 = (TYP-MA(TYP,5))/(0.618*ABS(TYP,5))
    CCC5 = (TYP-MA(TYP,7))/(0.618*ABS(TYP,7))
    CCC6 = (TYP-MA(TYP,9))/(0.618*ABS(TYP,9))
    CCC7 = (TYP-MA(TYP,11))/(0.618*ABS(TYP,11))
    CCC8 = (TYP-MA(TYP,13))/(0.618*ABS(TYP,13))
    CCC9 = (TYP-MA(TYP,15))/(0.618*ABS(TYP,15))
    CCC10 = (TYP-MA(TYP,17))/(0.618*ABS(TYP,17))
    CCC11 = (TYP-MA(TYP,19))/(0.618*ABS(TYP,19))
    MAMTM = (MA((MA(CLOSE-REF(CLOSE,12),6)),6))

    #cccx = range(ccc2,0,2) & range(ccc3,0,3) & CROSS(ccc5,0) & CROSS(ccc6,0) & CROSS(ccc7,0) & CROSS(ccc8,0) & CROSS(ccc9,0) & CROSS(ccc10,0) & CROSS(ccc11,0) 
    #cccB = range(ccc2,0,2) & range(ccc3,0,3) & CROSS(ccc5,-1) & CROSS(ccc6,-1) & CROSS(ccc7,-1) & CROSS(ccc8,-1) & CROSS(ccc9,-1) & CROSS(ccc10,-1) & CROSS(ccc11,-1))) & CROSS((ATAN((REF(MA(CLOSE,12),1)/REF(MA(CLOSE,12),2)-1)*100)*75.3),35) & (REF(VOL,1)/REF(MA(VOL,3),2))>1.618 & REF(CLOSE,2)/REF(OPEN,1)<1.0618 & REF(CLOSE,2)/REF(CLOSE,1)<1.099 & OPEN/REF(CLOSE,1)<1.0618
''' 


select(
    lambda : CCC / CCI[1] - 1 >= 0.0995,
    start_date=(n8),
	end_date=(n9),
)

# %%
# 选出涨停股
select(
    lambda : C / C[1] - 1 >= 0.0995,
    start_date=(n8),
	end_date=(n9),
)

# 选出最近30天K线实体最高价最低价差7%以内，最近100天K线实体最高价最低价差25%以内，
# 最近10天，收盘价大于60日均线的天数大于3天
select(
    lambda : ((HHV(MAX(C, O), 30) / LLV(MIN(C, O), 30) - 1 < 0.07)
              & (HHV(MAX(C, O), 100) / LLV(MIN(C, O), 100) - 1 > 0.25)
              & (COUNT(C > MA(C, 60), 10) > 3)
             ),
    start_date=(n8),
	end_date=(n9),
)

# 选出最近3天每天的成交量小于20日成交量均线，最近3天最低价低于20日均线，最高价高于20日均线
# 自定义选股回调函数
def callback(date, order_book_id, symbol):
    print("Cool, 在", date, "选出", order_book_id, symbol)

    
select(
    lambda : (EVERY(V < MA(V, 20) / 2, 3) & EVERY(L < MA(C, 20), 3) & EVERY(H > MA(C, 20), 3)),
    start_date=(n8),
	end_date=(n9),
    callback=callback,
)
# Out:
# lambda : C / C[1] - 1 >= 0.0995,
# [20180202]
# 20180202 000672.XSHE 上峰水泥
# 20180202 002128.XSHE 露天煤业
# 20180202 300058.XSHE 蓝色光标
# 20180202 300277.XSHE 海联讯
# 20180202 300364.XSHE 中文在线
# 20180202 300370.XSHE 安控科技
# 20180202 300550.XSHE 和仁科技
# 20180202 300738.XSHE 奥飞数据
# 20180202 300739.XSHE 明阳电路
# 20180202 600362.XSHG 江西铜业
# 20180202 600497.XSHG 驰宏锌锗
# 20180202 600583.XSHG 海油工程
# 20180202 600740.XSHG 山西焦化
# 20180202 600985.XSHG 雷鸣科化
# 20180202 601313.XSHG 江南嘉捷
# 20180202 601699.XSHG 潞安环能
# 20180202 601838.XSHG 成都银行
# 20180202 603009.XSHG 北特科技
# 20180202 603056.XSHG 德邦股份
# 20180202 603117.XSHG 万林股份
# 20180202 603356.XSHG 华菱精工
# 20180202 603499.XSHG 翔港科技
# 20180202 603506.XSHG 南都物业
#
# lambda : ((HHV(MAX(C, O), 30) / LLV(MIN(C, O), 30) - 1 < 0.07)
#               & (HHV(MAX(C, O), 100) / LLV(MIN(C, O), 100) - 1 > 0.25)
#               & (COUNT(C > MA(C, 60), 10) > 3)
#              ),
# [20180202]
# 20180202 600054.XSHG 黄山旅游
# 20180202 600368.XSHG 五洲交通
# 20180202 600785.XSHG 新华百货
#
# lambda : (EVERY(V < MA(V, 20) / 2, 3) & EVERY(L < MA(C, 20), 3) & EVERY(H > MA(C, 20), 3)),
# [20180202]

# %%
#N, M1, M2 = 27, 9, 3
#N, M1, M2 = 27, 9, 3
#RSV = (L-LLV(L,N))/(HHV(H,N)-LLV(L, N))*100
#K = EMA(RSV,(M1*2-1))
#D = EMA(K,(M2*2-1))
#J = K*3-D*2
#print(K, D, J)

#RSV = ((H-LLV(L,27))/(HHV(H,27)-LLV(H,27))*100)
#K = (EMA(RSV,(9*2-1)))
#D = (EMA(K,(3*2-1)))
#J = (K*3-D*2)

#kdj=CROSS(J,K)
print (RSV,K,D,J,kdj)


#N, M1, M2 = 27, 9, 3
#RSV = (L-LLV(L,27))/(HHV(H,27)-LLV(L, 27))*100
#RSV = ((H-LLV(L,27))/(HHV(H,27)-LLV(H,27))*100)
RSV = (HHV(H,1)-LLV(L,27))/(HHV(H,27)-LLV(L,27))*100

K = EMA(RSV, (9 * 2 - 1))
D = EMA(K, (3 * 2 - 1))
J = K * 3 - D * 2
print(K, D, J)

f, (ax1, ax2) = plt.subplots(2, 1)
ax1.plot(H.series, label="H")
ax1.plot(MA(H, 7).series, label="ma7")
ax1.plot(MA(H, 11).series, label="ma11")
ax1.plot(MA(H, 22).series, label="ma22")
ax1.plot(MA(H, 66).series, label="ma66")
ax1.set_xlim(0)
#ax1.set_ylim(0)
ax2.plot(K.series, label="K")
ax2.plot(D.series, label="D")
ax2.plot(J.series, label="J")
ax2.set_xlim(-27)
#ax1.set_ylim(22)

buy_signal = (CROSS(IF(D<50,J,D),D) and CROSS(IF(D<50,K,J),D)) #CROSS(J, K)

sell_signal = (CROSS(D,IF(D>80,J,D)) and CROSS(D,IF(D>80,K,J))) #CROSS(K, J)

plt.plot(np.where(buy_signal.series)[0], K.series[np.where(buy_signal.series)[0]], "^", label="buy", markersize=12, color="red")
plt.plot(np.where(sell_signal.series)[0], J.series[np.where(sell_signal.series)[0]], "v", label="sell", markersize=12, color="green")
#plt.legend(loc="best")
plt.show()
# Out:
# 61.685740798020326 84.49780227203001 87.74779158857099 77.99782363894806 False
# 84.49780227203001 87.74779158857099 77.99782363894806

# %%
#N, M1, M2 = 27, 9, 3
RSV = ((HHV(H,1)-LLV(L,27))/(HHV(H,27)-LLV(L,27))*100)

K = (EMA(((HHV(H,1)-LLV(L,27))/(HHV(H,27)-LLV(L,27))*100),(9*2-1)))
D = (EMA((EMA(((HHV(H,1)-LLV(L,27))/(HHV(H,27)-LLV(L,27))*100),(9*2-1))),(3*2-1)))
J = ((EMA(((HHV(H,1)-LLV(L,27))/(HHV(H,27)-LLV(L,27))*100),(9*2-1)))*3-(EMA((EMA(((HHV(H,1)-LLV(L,27))/(HHV(H,27)-LLV(L,27))*100),(9*2-1))),(3*2-1)))*2)


kdj=(CROSS(IF(J<40,J,D),D) or CROSS(IF(K<40,K,J),J))

print ("k",K,"d",D,"j",J,"kdj",kdj)


select(
    lambda : C  >= 600,
    start_date=(n8),
	end_date=(n9),
)
# Out:
# k 43.23849253467336 d 45.03957107845891 j 39.63633544710227 kdj False
# lambda : C  >= 600,
# [20180202]
# No data for 002926.XSHE
# 20180202 600519.XSHG 贵州茅台
# [20180201]
# 20180201 600519.XSHG 贵州茅台
# [20180131]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-131-98df0b60d6cd> in <module>()
#      15     lambda : C  >= 600,
#      16     start_date=(n8),
# ---> 17         end_date=(n9),
#      18 )
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/funcat/helper.py in wrapper(*args, **kwargs)
#      15         try:
#      16             old_settings = np.seterr(all='ignore')
# ---> 17             return func(*args, **kwargs)
#      18         finally:
#      19             np.seterr(**old_settings)  # reset to default
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/funcat/helper.py in select(func, start_date, end_date, callback)
#      49
#      50         for order_book_id in order_book_id_list:
# ---> 51             choose(order_book_id, func, callback)
#      52
#      53     print("")
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/funcat/helper.py in choose(order_book_id, func, callback)
#      24     set_current_security(order_book_id)
#      25     try:
# ---> 26         if func():
#      27             date = ExecutionContext.get_current_date()
#      28             callback(date, order_book_id, symbol(order_book_id))
#
# <ipython-input-131-98df0b60d6cd> in <lambda>()
#      13
#      14 select(
# ---> 15     lambda : C  >= 600,
#      16     start_date=(n8),
#      17         end_date=(n9),
#
# ~/anaconda3/envs/THS/lib/python3.5/site-packages/funcat/utils.py in wrapper(*args, **kwargs)
#      24         try:
#      25             # print(func, args, kwargs)
# ---> 26             return func(*args, **kwargs)
#      27         except (ValueError, IndexError) as e:
#      28             raise FormulaException(e)
#
# KeyboardInterrupt:

# %%
# VC 选股！！！
M=14
TYP = ((H+L+C)/3)
CCI = ((((H+L+C)/3)-MA(((H+L+C)/3),14))/(0.015*AVEDEV(((H+L+C)/3),14)))
VCCI = ((V-MA(V,14))/(0.015*AVEDEV(V,14)))
VC = ((((((((H+L+C)/3)-MA(((H+L+C)/3),14))/(0.015*AVEDEV(((H+L+C)/3),14)))+((V-MA(V,14))/(0.015*AVEDEV(V,14))))-MA((((((H+L+C)/3)-MA(((H+L+C)/3),14))/(0.015*AVEDEV(((H+L+C)/3),14)))+((V-MA(V,14))/(0.015*AVEDEV(V,14)))),14))/(0.015*AVEDEV((((((H+L+C)/3)-MA(((H+L+C)/3),14))/(0.015*AVEDEV(((H+L+C)/3),14)))+((V-MA(V,14))/(0.015*AVEDEV(V,14)))),14))))


BBB= CROSS(((((H+L+C)/3)-MA(((H+L+C)/3),14))/(0.015*AVEDEV(((H+L+C)/3),14))) or ((((((((H+L+C)/3)-MA(((H+L+C)/3),14))/(0.015*AVEDEV(((H+L+C)/3),14)))+((V-MA(V,14))/(0.015*AVEDEV(V,14))))-MA((((((H+L+C)/3)-MA(((H+L+C)/3),14))/(0.015*AVEDEV(((H+L+C)/3),14)))+((V-MA(V,14))/(0.015*AVEDEV(V,14)))),14))/(0.015*AVEDEV((((((H+L+C)/3)-MA(((H+L+C)/3),14))/(0.015*AVEDEV(((H+L+C)/3),14)))+((V-MA(V,14))/(0.015*AVEDEV(V,14)))),14))))

,101 or -101)


print (BBB)
# Out:
# False

# %%
select(
    lambda : C  >= 0,
    start_date=(n8),
	end_date=(n9),
)
# Out:
# lambda : C  >= 0,
# [20180202]
# 20180202 000001.XSHE 平安银行
# 20180202 000002.XSHE 万科A
# 20180202 000004.XSHE 国农科技
# 20180202 000005.XSHE 世纪星源
# 20180202 000008.XSHE 神州高铁
# 20180202 000009.XSHE 中国宝安
# 20180202 000010.XSHE 美丽生态
# 20180202 000011.XSHE 深物业A
# 20180202 000012.XSHE 南玻A
# 20180202 000014.XSHE 沙河股份
# 20180202 000016.XSHE 深康佳A
# 20180202 000017.XSHE 深中华A
# 20180202 000020.XSHE 深华发A
# 20180202 000021.XSHE 深科技
# 20180202 000023.XSHE 深天地A
# 20180202 000025.XSHE 特力A
# 20180202 000026.XSHE 飞亚达A
# 20180202 000027.XSHE 深圳能源
# 20180202 000028.XSHE 国药一致
# 20180202 000030.XSHE 富奥股份
# 20180202 000032.XSHE 深桑达A
# 20180202 000036.XSHE 华联控股
# 20180202 000037.XSHE 深南电A
# 20180202 000038.XSHE 深大通
# 20180202 000039.XSHE 中集集团
# 20180202 000040.XSHE 东旭蓝天
# 20180202 000042.XSHE 中洲控股
# 20180202 000043.XSHE 中航地产
# 20180202 000045.XSHE 深纺织A
# 20180202 000048.XSHE 康达尔
# 20180202 000049.XSHE 德赛电池
# 20180202 000050.XSHE 深天马A
# 20180202 000055.XSHE 方大集团
# 20180202 000058.XSHE 深赛格
# 20180202 000059.XSHE 华锦股份
# 20180202 000060.XSHE 中金岭南
# 20180202 000061.XSHE 农产品
# 20180202 000062.XSHE 深圳华强
# 20180202 000063.XSHE 中兴通讯
# 20180202 000065.XSHE 北方国际
# 20180202 000066.XSHE 中国长城
# 20180202 000068.XSHE 华控赛格
# 20180202 000069.XSHE 华侨城A
# 20180202 000070.XSHE 特发信息
# 20180202 000078.XSHE 海王生物
# 20180202 000088.XSHE 盐田港
# 20180202 000089.XSHE 深圳机场
# 20180202 000090.XSHE 天健集团
# 20180202 000096.XSHE 广聚能源
# 20180202 000099.XSHE 中信海直
# 20180202 000100.XSHE TCL集团
# 20180202 000150.XSHE 宜华健康
# 20180202 000151.XSHE 中成股份
# 20180202 000153.XSHE 丰原药业
# 20180202 000155.XSHE 川化股份
# 20180202 000157.XSHE 中联重科
# 20180202 000158.XSHE 常山北明
# 20180202 000159.XSHE 国际实业
# 20180202 000166.XSHE 申万宏源
# 20180202 000301.XSHE 东方市场
# 20180202 000333.XSHE 美的集团
# 20180202 000338.XSHE 潍柴动力
# 20180202 000400.XSHE 许继电气
# 20180202 000401.XSHE 冀东水泥
# 20180202 000402.XSHE 金融街
# 20180202 000403.XSHE ST生化
# 20180202 000404.XSHE 华意压缩
# 20180202 000407.XSHE 胜利股份
# 20180202 000408.XSHE 藏格控股
# 20180202 000409.XSHE 山东地矿
# 20180202 000410.XSHE *ST沈机
# 20180202 000411.XSHE 英特集团
# 20180202 000413.XSHE 东旭光电
# 20180202 000416.XSHE 民生控股
# 20180202 000417.XSHE 合肥百货
# 20180202 000418.XSHE 小天鹅A
# 20180202 000419.XSHE 通程控股
# 20180202 000420.XSHE 吉林化纤
# 20180202 000421.XSHE 南京公用
# 20180202 000422.XSHE 湖北宜化
# 20180202 000423.XSHE 东阿阿胶
# 20180202 000425.XSHE 徐工机械
# 20180202 000426.XSHE 兴业矿业
# 20180202 000428.XSHE 华天酒店
# 20180202 000429.XSHE 粤高速A
# 20180202 000430.XSHE 张家界
# 20180202 000488.XSHE 晨鸣纸业
# 20180202 000498.XSHE 山东路桥
# 20180202 000501.XSHE 鄂武商A
# 20180202 000502.XSHE 绿景控股
# 20180202 000503.XSHE 海虹控股
# 20180202 000504.XSHE 南华生物
# 20180202 000505.XSHE 珠江控股
# 20180202 000506.XSHE 中润资源
# 20180202 000507.XSHE 珠海港
# 20180202 000510.XSHE 金路集团
# 20180202 000513.XSHE 丽珠集团
# 20180202 000514.XSHE 渝开发
# 20180202 000517.XSHE 荣安地产
# 20180202 000518.XSHE 四环生物
# 20180202 000519.XSHE 中兵红箭
# 20180202 000520.XSHE 长航凤凰
# 20180202 000521.XSHE 美菱电器
# 20180202 000523.XSHE 广州浪奇
# 20180202 000524.XSHE 岭南控股
# 20180202 000525.XSHE 红太阳
# 20180202 000526.XSHE *ST紫学
# 20180202 000528.XSHE 柳工
# 20180202 000529.XSHE 广弘控股
# 20180202 000530.XSHE 大冷股份
# 20180202 000531.XSHE 穗恒运A
# 20180202 000532.XSHE 华金资本
# 20180202 000536.XSHE 华映科技
# 20180202 000537.XSHE 广宇发展
# 20180202 000538.XSHE 云南白药
# 20180202 000539.XSHE 粤电力A
# 20180202 000541.XSHE 佛山照明
# 20180202 000543.XSHE 皖能电力
# 20180202 000544.XSHE 中原环保
# 20180202 000545.XSHE 金浦钛业
# 20180202 000546.XSHE 金圆股份
# 20180202 000548.XSHE 湖南投资
# 20180202 000550.XSHE 江铃汽车
# 20180202 000551.XSHE 创元科技
# 20180202 000552.XSHE 靖远煤电
# 20180202 000553.XSHE 沙隆达A
# 20180202 000554.XSHE 泰山石油
# 20180202 000555.XSHE 神州信息
# 20180202 000557.XSHE 西部创业
# 20180202 000558.XSHE 莱茵体育
# 20180202 000559.XSHE 万向钱潮
# 20180202 000560.XSHE 昆百大A
# 20180202 000561.XSHE 烽火电子
# 20180202 000563.XSHE 陕国投A
# 20180202 000565.XSHE 渝三峡A
# 20180202 000567.XSHE 海德股份
# 20180202 000568.XSHE 泸州老窖
# 20180202 000570.XSHE 苏常柴A
# 20180202 000571.XSHE 新大洲A
# 20180202 000572.XSHE 海马汽车
# 20180202 000573.XSHE 粤宏远A
# 20180202 000576.XSHE 广东甘化
# 20180202 000581.XSHE 威孚高科
# 20180202 000582.XSHE 北部湾港
# 20180202 000584.XSHE 哈工智能
# 20180202 000585.XSHE 东北电气
# 20180202 000586.XSHE 汇源通信
# 20180202 000587.XSHE 金洲慈航
# 20180202 000589.XSHE 黔轮胎A
# 20180202 000590.XSHE 启迪古汉
# 20180202 000591.XSHE 太阳能
# 20180202 000592.XSHE 平潭发展
# 20180202 000593.XSHE 大通燃气
# 20180202 000595.XSHE *ST宝实
# 20180202 000596.XSHE 古井贡酒
# 20180202 000597.XSHE 东北制药
# 20180202 000598.XSHE 兴蓉环境
# 20180202 000599.XSHE 青岛双星
# 20180202 000600.XSHE 建投能源
# 20180202 000601.XSHE 韶能股份
# 20180202 000603.XSHE 盛达矿业
# 20180202 000605.XSHE 渤海股份
# 20180202 000607.XSHE 华媒控股
# 20180202 000608.XSHE 阳光股份
# 20180202 000609.XSHE 绵石投资
# 20180202 000610.XSHE 西安旅游
# 20180202 000611.XSHE 天首发展
# 20180202 000612.XSHE 焦作万方
# 20180202 000615.XSHE 京汉股份
# 20180202 000617.XSHE 中油资本
# 20180202 000619.XSHE 海螺型材
# 20180202 000620.XSHE 新华联
# 20180202 000622.XSHE 恒立实业
# 20180202 000623.XSHE 吉林敖东
# 20180202 000625.XSHE 长安汽车
# 20180202 000626.XSHE 远大控股
# 20180202 000627.XSHE 天茂集团
# 20180202 000628.XSHE 高新发展
# 20180202 000630.XSHE 铜陵有色
# 20180202 000631.XSHE 顺发恒业
# 20180202 000632.XSHE 三木集团
# 20180202 000633.XSHE 合金投资
# 20180202 000635.XSHE 英力特
# 20180202 000636.XSHE 风华高科
# 20180202 000637.XSHE 茂化实华
# 20180202 000638.XSHE 万方发展
# 20180202 000639.XSHE 西王食品
# 20180202 000650.XSHE 仁和药业
# 20180202 000651.XSHE 格力电器
# 20180202 000652.XSHE 泰达股份
# 20180202 000655.XSHE 金岭矿业
# 20180202 000656.XSHE 金科股份
# 20180202 000657.XSHE 中钨高新
# 20180202 000659.XSHE *ST中富
# 20180202 000661.XSHE 长春高新
# 20180202 000663.XSHE 永安林业
# 20180202 000665.XSHE 湖北广电
# 20180202 000666.XSHE 经纬纺机
# 20180202 000667.XSHE 美好置业
# 20180202 000668.XSHE 荣丰控股
# 20180202 000669.XSHE 金鸿控股
# 20180202 000670.XSHE 盈方微
# 20180202 000671.XSHE 阳光城
# 20180202 000672.XSHE 上峰水泥
# 20180202 000676.XSHE 智度股份
# 20180202 000677.XSHE 恒天海龙
# 20180202 000678.XSHE 襄阳轴承
# 20180202 000679.XSHE 大连友谊
# 20180202 000680.XSHE 山推股份
# 20180202 000681.XSHE 视觉中国
# 20180202 000682.XSHE 东方电子
# 20180202 000683.XSHE 远兴能源
# 20180202 000685.XSHE 中山公用
# 20180202 000686.XSHE 东北证券
# 20180202 000687.XSHE 华讯方舟
# 20180202 000690.XSHE 宝新能源
# 20180202 000691.XSHE 亚太实业
# 20180202 000692.XSHE 惠天热电
# 20180202 000695.XSHE 滨海能源
# 20180202 000697.XSHE 炼石有色
# 20180202 000698.XSHE 沈阳化工
# 20180202 000700.XSHE 模塑科技
# 20180202 000701.XSHE 厦门信达
# 20180202 000702.XSHE 正虹科技
# 20180202 000705.XSHE 浙江震元
# 20180202 000707.XSHE 双环科技
# 20180202 000708.XSHE 大冶特钢
# 20180202 000709.XSHE 河钢股份
# 20180202 000710.XSHE 贝瑞基因
# 20180202 000711.XSHE 京蓝科技
# 20180202 000712.XSHE 锦龙股份
# 20180202 000713.XSHE 丰乐种业
# 20180202 000715.XSHE 中兴商业
# 20180202 000716.XSHE 黑芝麻
# 20180202 000717.XSHE 韶钢松山
# 20180202 000718.XSHE 苏宁环球
# 20180202 000719.XSHE 中原传媒
# 20180202 000720.XSHE 新能泰山
# 20180202 000721.XSHE 西安饮食
# 20180202 000722.XSHE 湖南发展
# 20180202 000723.XSHE 美锦能源
# 20180202 000725.XSHE 京东方A
# 20180202 000726.XSHE 鲁泰A
# 20180202 000727.XSHE 华东科技
# 20180202 000728.XSHE 国元证券
# 20180202 000729.XSHE 燕京啤酒
# 20180202 000731.XSHE 四川美丰
# 20180202 000732.XSHE 泰禾集团
# 20180202 000733.XSHE 振华科技
# 20180202 000735.XSHE 罗牛山
# 20180202 000736.XSHE 中交地产
# 20180202 000738.XSHE 航发控制
# 20180202 000739.XSHE 普洛药业
# 20180202 000750.XSHE 国海证券
# 20180202 000751.XSHE 锌业股份
# 20180202 000752.XSHE 西藏发展
# 20180202 000753.XSHE 漳州发展
# 20180202 000755.XSHE *ST三维
# 20180202 000758.XSHE 中色股份
# 20180202 000759.XSHE 中百集团
# 20180202 000760.XSHE 斯太尔
# 20180202 000761.XSHE 本钢板材
# 20180202 000762.XSHE 西藏矿业
# 20180202 000767.XSHE 漳泽电力
# 20180202 000768.XSHE 中航飞机
# 20180202 000776.XSHE 广发证券
# 20180202 000777.XSHE 中核科技
# 20180202 000778.XSHE 新兴铸管
# 20180202 000779.XSHE 三毛派神
# 20180202 000780.XSHE *ST平能
# 20180202 000782.XSHE 美达股份
# 20180202 000783.XSHE 长江证券
# 20180202 000785.XSHE 武汉中商
# 20180202 000786.XSHE 北新建材
# 20180202 000788.XSHE 北大医药
# 20180202 000789.XSHE 万年青
# 20180202 000790.XSHE 泰合健康
# 20180202 000791.XSHE 甘肃电投
# 20180202 000792.XSHE 盐湖股份
# 20180202 000795.XSHE 英洛华
# 20180202 000797.XSHE 中国武夷
# 20180202 000798.XSHE 中水渔业
# 20180202 000799.XSHE 酒鬼酒
# 20180202 000800.XSHE 一汽轿车
# 20180202 000801.XSHE 四川九洲
# 20180202 000802.XSHE 北京文化
# 20180202 000803.XSHE *ST金宇
# 20180202 000806.XSHE 银河生物
# 20180202 000807.XSHE 云铝股份
# 20180202 000809.XSHE *ST新城
# 20180202 000810.XSHE 创维数字
# 20180202 000811.XSHE 冰轮环境
# 20180202 000813.XSHE 德展健康
# 20180202 000815.XSHE 美利云
# 20180202 000816.XSHE 智慧农业
# 20180202 000818.XSHE 方大化工
# 20180202 000819.XSHE 岳阳兴长
# 20180202 000821.XSHE 京山轻机
# 20180202 000822.XSHE 山东海化
# 20180202 000823.XSHE 超声电子
# 20180202 000825.XSHE 太钢不锈
# 20180202 000826.XSHE 启迪桑德
# 20180202 000828.XSHE 东莞控股
# 20180202 000829.XSHE 天音控股
# 20180202 000830.XSHE 鲁西化工
# 20180202 000831.XSHE 五矿稀土
# 20180202 000833.XSHE 贵糖股份
# 20180202 000835.XSHE 长城动漫
# 20180202 000836.XSHE 鑫茂科技
# 20180202 000837.XSHE 秦川机床
# 20180202 000838.XSHE 财信发展
# 20180202 000839.XSHE 中信国安
# 20180202 000848.XSHE 承德露露
# 20180202 000850.XSHE 华茂股份
# 20180202 000851.XSHE 高鸿股份
# 20180202 000852.XSHE 石化机械
# 20180202 000856.XSHE 冀东装备
# 20180202 000858.XSHE 五粮液
# 20180202 000859.XSHE 国风塑业
# 20180202 000860.XSHE 顺鑫农业
# 20180202 000861.XSHE 海印股份
# 20180202 000862.XSHE 银星能源
# 20180202 000863.XSHE 三湘印象
# 20180202 000868.XSHE 安凯客车
# 20180202 000869.XSHE 张裕A
# 20180202 000875.XSHE 吉电股份
# 20180202 000876.XSHE 新希望
# 20180202 000877.XSHE 天山股份
# 20180202 000878.XSHE 云南铜业
# 20180202 000880.XSHE 潍柴重机
# 20180202 000881.XSHE 中广核技
# 20180202 000882.XSHE 华联股份
# 20180202 000883.XSHE 湖北能源
# 20180202 000885.XSHE 同力水泥
# 20180202 000886.XSHE 海南高速
# 20180202 000887.XSHE 中鼎股份
# 20180202 000888.XSHE 峨眉山A
# 20180202 000889.XSHE 茂业通信
# 20180202 000890.XSHE 法尔胜
# 20180202 000892.XSHE 欢瑞世纪
# 20180202 000893.XSHE 东凌国际
# 20180202 000895.XSHE 双汇发展
# 20180202 000897.XSHE 津滨发展
# 20180202 000898.XSHE 鞍钢股份
# 20180202 000899.XSHE 赣能股份
# 20180202 000901.XSHE 航天科技
# 20180202 000902.XSHE 新洋丰
# 20180202 000903.XSHE 云内动力
# 20180202 000905.XSHE 厦门港务
# 20180202 000906.XSHE 浙商中拓
# 20180202 000908.XSHE 景峰医药
# 20180202 000909.XSHE 数源科技
# 20180202 000910.XSHE 大亚圣象
# 20180202 000911.XSHE 南宁糖业
# 20180202 000913.XSHE 钱江摩托
# 20180202 000915.XSHE 山大华特
# 20180202 000917.XSHE 电广传媒
# 20180202 000918.XSHE 嘉凯城
# 20180202 000919.XSHE 金陵药业
# 20180202 000920.XSHE 南方汇通
# 20180202 000921.XSHE 海信科龙
# 20180202 000922.XSHE *ST佳电
# 20180202 000923.XSHE 河北宣工
# 20180202 000925.XSHE 众合科技
# 20180202 000926.XSHE 福星股份
# 20180202 000927.XSHE 一汽夏利
# 20180202 000928.XSHE 中钢国际
# 20180202 000929.XSHE 兰州黄河
# 20180202 000931.XSHE 中关村
# 20180202 000932.XSHE *ST华菱
# 20180202 000933.XSHE 神火股份
# 20180202 300160.XSHE 秀强股份
# 20180202 300161.XSHE 华中数控
# 20180202 300162.XSHE 雷曼股份
# 20180202 300163.XSHE 先锋新材
# 20180202 300164.XSHE 通源石油
# 20180202 300165.XSHE 天瑞仪器
# 20180202 300166.XSHE 东方国信
# 20180202 300168.XSHE 万达信息
# 20180202 300169.XSHE 天晟新材
# 20180202 300170.XSHE 汉得信息
# 20180202 300171.XSHE 东富龙
# 20180202 300172.XSHE 中电环保
# 20180202 300174.XSHE 元力股份
# 20180202 300175.XSHE 朗源股份
# 20180202 300176.XSHE 鸿特精密
# 20180202 300177.XSHE 中海达
# 20180202 300178.XSHE 腾邦国际
# 20180202 300179.XSHE 四方达
# 20180202 300180.XSHE 华峰超纤
# 20180202 300181.XSHE 佐力药业
# 20180202 300182.XSHE 捷成股份
# 20180202 300183.XSHE 东软载波
# 20180202 300184.XSHE 力源信息
# 20180202 300185.XSHE 通裕重工
# 20180202 300187.XSHE 永清环保
# 20180202 300188.XSHE 美亚柏科
# 20180202 300189.XSHE 神农基因
# 20180202 300190.XSHE 维尔利
# 20180202 300191.XSHE 潜能恒信
# 20180202 300192.XSHE 科斯伍德
# 20180202 300193.XSHE 佳士科技
# 20180202 300194.XSHE 福安药业
# 20180202 300195.XSHE 长荣股份
# 20180202 300196.XSHE 长海股份
# 20180202 300197.XSHE 铁汉生态
# 20180202 300199.XSHE 翰宇药业
# 20180202 300200.XSHE 高盟新材
# 20180202 300201.XSHE 海伦哲
# 20180202 300202.XSHE 聚龙股份
# 20180202 300203.XSHE 聚光科技
# 20180202 300204.XSHE 舒泰神
# 20180202 300205.XSHE 天喻信息
# 20180202 300206.XSHE 理邦仪器
# 20180202 300207.XSHE 欣旺达
# 20180202 300208.XSHE 恒顺众昇
# 20180202 300209.XSHE 天泽信息
# 20180202 300210.XSHE 森远股份
# 20180202 300211.XSHE 亿通科技
# 20180202 300212.XSHE 易华录
# 20180202 300213.XSHE 佳讯飞鸿
# 20180202 300214.XSHE 日科化学
# 20180202 300215.XSHE 电科院
# 20180202 300216.XSHE 千山药机
# 20180202 300217.XSHE 东方电热
# 20180202 300218.XSHE 安利股份
# 20180202 300219.XSHE 鸿利智汇
# 20180202 300220.XSHE 金运激光
# 20180202 300221.XSHE 银禧科技
# 20180202 300222.XSHE 科大智能
# 20180202 300223.XSHE 北京君正
# 20180202 300224.XSHE 正海磁材
# 20180202 300225.XSHE 金力泰
# 20180202 300226.XSHE 上海钢联
# 20180202 300227.XSHE 光韵达
# 20180202 300228.XSHE 富瑞特装
# 20180202 300229.XSHE 拓尔思
# 20180202 300230.XSHE 永利股份
# 20180202 300231.XSHE 银信科技
# 20180202 300232.XSHE 洲明科技
# 20180202 300233.XSHE 金城医药
# 20180202 300234.XSHE 开尔新材
# 20180202 300235.XSHE 方直科技
# 20180202 300236.XSHE 上海新阳
# 20180202 300237.XSHE 美晨生态
# 20180202 300239.XSHE 东宝生物
# 20180202 300241.XSHE 瑞丰光电
# 20180202 300242.XSHE 明家联合
# 20180202 300243.XSHE 瑞丰高材
# 20180202 300244.XSHE 迪安诊断
# 20180202 300245.XSHE 天玑科技
# 20180202 300246.XSHE 宝莱特
# 20180202 300247.XSHE 乐金健康
# 20180202 300248.XSHE 新开普
# 20180202 300249.XSHE 依米康
# 20180202 300250.XSHE 初灵信息
# 20180202 300251.XSHE 光线传媒
# 20180202 300252.XSHE 金信诺
# 20180202 300253.XSHE 卫宁健康
# 20180202 300254.XSHE 仟源医药
# 20180202 300255.XSHE 常山药业
# 20180202 300256.XSHE 星星科技
# 20180202 300257.XSHE 开山股份
# 20180202 300258.XSHE 精锻科技
# 20180202 300259.XSHE 新天科技
# 20180202 300260.XSHE 新莱应材
# 20180202 300261.XSHE 雅本化学
# 20180202 300262.XSHE 巴安水务
# 20180202 300263.XSHE 隆华节能
# 20180202 300264.XSHE 佳创视讯
# 20180202 300265.XSHE 通光线缆
# 20180202 300266.XSHE 兴源环境
# 20180202 300267.XSHE 尔康制药
# 20180202 300268.XSHE 佳沃股份
# 20180202 300269.XSHE 联建光电
# 20180202 300270.XSHE 中威电子
# 20180202 300271.XSHE 华宇软件
# 20180202 300272.XSHE 开能环保
# 20180202 300274.XSHE 阳光电源
# 20180202 300275.XSHE 梅安森
# 20180202 300276.XSHE 三丰智能
# 20180202 300277.XSHE 海联讯
# 20180202 300280.XSHE 南通锻压
# 20180202 300281.XSHE 金明精机
# 20180202 300282.XSHE 汇冠股份
# 20180202 300283.XSHE 温州宏丰
# 20180202 300284.XSHE 苏交科
# 20180202 300285.XSHE 国瓷材料
# 20180202 300286.XSHE 安科瑞
# 20180202 300287.XSHE 飞利信
# 20180202 300288.XSHE 朗玛信息
# 20180202 300289.XSHE 利德曼
# 20180202 300290.XSHE 荣科科技
# 20180202 300291.XSHE 华录百纳
# 20180202 300293.XSHE 蓝英装备
# 20180202 300294.XSHE 博雅生物
# 20180202 300295.XSHE 三六五网
# 20180202 300296.XSHE 利亚德
# 20180202 300297.XSHE 蓝盾股份
# 20180202 300298.XSHE 三诺生物
# 20180202 300299.XSHE 富春股份
# 20180202 300300.XSHE 汉鼎宇佑
# 20180202 300301.XSHE 长方集团
# 20180202 300302.XSHE 同有科技
# 20180202 300303.XSHE 聚飞光电
# 20180202 300304.XSHE 云意电气
# 20180202 300305.XSHE 裕兴股份
# 20180202 300306.XSHE 远方信息
# 20180202 300307.XSHE 慈星股份
# 20180202 300308.XSHE 中际旭创
# 20180202 300309.XSHE 吉艾科技
# 20180202 300310.XSHE 宜通世纪
# 20180202 300311.XSHE 任子行
# 20180202 300313.XSHE 天山生物
# 20180202 300314.XSHE 戴维医疗
# 20180202 300315.XSHE 掌趣科技
# 20180202 300316.XSHE 晶盛机电
# 20180202 300317.XSHE 珈伟股份
# 20180202 300318.XSHE 博晖创新
# 20180202 300319.XSHE 麦捷科技
# 20180202 300320.XSHE 海达股份
# 20180202 300321.XSHE 同大股份
# 20180202 300322.XSHE 硕贝德
# 20180202 300323.XSHE 华灿光电
# 20180202 300324.XSHE 旋极信息
# 20180202 300498.XSHE 温氏股份
# 20180202 300499.XSHE 高澜股份
# 20180202 300500.XSHE 启迪设计
# 20180202 300501.XSHE 海顺新材
# 20180202 300502.XSHE 新易盛
# 20180202 300503.XSHE 昊志机电
# 20180202 300505.XSHE 川金诺
# 20180202 300506.XSHE 名家汇
# 20180202 300507.XSHE 苏奥传感
# 20180202 300508.XSHE 维宏股份
# 20180202 300509.XSHE 新美星
# 20180202 300510.XSHE 金冠电气
# 20180202 300511.XSHE 雪榕生物
# 20180202 300512.XSHE 中亚股份
# 20180202 300513.XSHE 恒泰实达
# 20180202 300514.XSHE 友讯达
# 20180202 300515.XSHE 三德科技
# 20180202 300516.XSHE 久之洋
# 20180202 300517.XSHE 海波重科
# 20180202 300518.XSHE 盛讯达
# 20180202 300519.XSHE 新光药业
# 20180202 300520.XSHE 科大国创
# 20180202 300521.XSHE 爱司凯
# 20180202 300522.XSHE 世名科技
# 20180202 300525.XSHE 博思软件
# 20180202 300526.XSHE 中潜股份
# 20180202 300527.XSHE 华舟应急
# 20180202 300528.XSHE 幸福蓝海
# 20180202 300529.XSHE 健帆生物
# 20180202 300530.XSHE 达志科技
# 20180202 300531.XSHE 优博讯
# 20180202 300532.XSHE 今天国际
# 20180202 300533.XSHE 冰川网络
# 20180202 300534.XSHE 陇神戎发
# 20180202 300535.XSHE 达威股份
# 20180202 300536.XSHE 农尚环境
# 20180202 300537.XSHE 广信材料
# 20180202 300538.XSHE 同益股份
# 20180202 300539.XSHE 横河模具
# 20180202 300540.XSHE 深冷股份
# 20180202 300541.XSHE 先进数通
# 20180202 300542.XSHE 新晨科技
# 20180202 300543.XSHE 朗科智能
# 20180202 300545.XSHE 联得装备
# 20180202 300546.XSHE 雄帝科技
# 20180202 300547.XSHE 川环科技
# 20180202 300548.XSHE 博创科技
# 20180202 300549.XSHE 优德精密
# 20180202 300550.XSHE 和仁科技
# 20180202 300551.XSHE 古鳌科技
# 20180202 300552.XSHE 万集科技
# 20180202 300553.XSHE 集智股份
# 20180202 300554.XSHE 三超新材
# 20180202 300555.XSHE 路通视信
# 20180202 300556.XSHE 丝路视觉
# 20180202 300557.XSHE 理工光科
# 20180202 300558.XSHE 贝达药业
# 20180202 300559.XSHE 佳发安泰
# 20180202 300560.XSHE 中富通
# 20180202 300561.XSHE 汇金科技
# 20180202 300562.XSHE 乐心医疗
# 20180202 300563.XSHE 神宇股份
# 20180202 300565.XSHE 科信技术
# 20180202 300566.XSHE 激智科技
# 20180202 300567.XSHE 精测电子
# 20180202 300568.XSHE 星源材质
# 20180202 300569.XSHE 天能重工
# 20180202 300570.XSHE 太辰光
# 20180202 300571.XSHE 平治信息
# 20180202 300572.XSHE 安车检测
# 20180202 300573.XSHE 兴齐眼药
# 20180202 300575.XSHE 中旗股份
# 20180202 300576.XSHE 容大感光
# 20180202 300577.XSHE 开润股份
# 20180202 300579.XSHE 数字认证
# 20180202 300581.XSHE 晨曦航空
# 20180202 300582.XSHE 英飞特
# 20180202 300583.XSHE 赛托生物
# 20180202 300584.XSHE 海辰药业
# 20180202 300585.XSHE 奥联电子
# 20180202 300586.XSHE 美联新材
# 20180202 300587.XSHE 天铁股份
# 20180202 300588.XSHE 熙菱信息
# 20180202 300589.XSHE 江龙船艇
# 20180202 300590.XSHE 移为通信
# 20180202 300591.XSHE 万里马
# 20180202 300592.XSHE 华凯创意
# 20180202 300595.XSHE 欧普康视
# 20180202 300596.XSHE 利安隆
# 20180202 300597.XSHE 吉大通信
# 20180202 300598.XSHE 诚迈科技
# 20180202 300599.XSHE 雄塑科技
# 20180202 300600.XSHE 瑞特股份
# 20180202 300601.XSHE 康泰生物
# 20180202 300602.XSHE 飞荣达
# 20180202 300603.XSHE 立昂技术
# 20180202 300604.XSHE 长川科技
# 20180202 300605.XSHE 恒锋信息
# 20180202 300606.XSHE 金太阳
# 20180202 300607.XSHE 拓斯达
# 20180202 300608.XSHE 思特奇
# 20180202 300609.XSHE 汇纳科技
# 20180202 300610.XSHE 晨化股份
# 20180202 300611.XSHE 美力科技
# 20180202 300612.XSHE 宣亚国际
# 20180202 300613.XSHE 富瀚微
# 20180202 300615.XSHE 欣天科技
# 20180202 300616.XSHE 尚品宅配
# 20180202 300617.XSHE 安靠智电
# 20180202 300618.XSHE 寒锐钴业
# 20180202 300619.XSHE 金银河
# 20180202 300620.XSHE 光库科技
# 20180202 300621.XSHE 维业股份
# 20180202 300622.XSHE 博士眼镜
# 20180202 300623.XSHE 捷捷微电
# 20180202 300624.XSHE 万兴科技
# 20180202 300625.XSHE 三雄极光
# 20180202 300626.XSHE 华瑞股份
# 20180202 300627.XSHE 华测导航
# 20180202 300628.XSHE 亿联网络
# 20180202 300629.XSHE 新劲刚
# 20180202 300630.XSHE 普利制药
# 20180202 300631.XSHE 久吾高科
# 20180202 300632.XSHE 光莆股份
# 20180202 300633.XSHE 开立医疗
# 20180202 300635.XSHE 达安股份
# 20180202 300636.XSHE 同和药业
# 20180202 300637.XSHE 扬帆新材
# 20180202 300638.XSHE 广和通
# 20180202 300639.XSHE 凯普生物
# 20180202 300640.XSHE 德艺文创
# 20180202 300641.XSHE 正丹股份
# 20180202 300642.XSHE 透景生命
# 20180202 300643.XSHE 万通智控
# 20180202 300645.XSHE 正元智慧
# 20180202 300647.XSHE 超频三
# 20180202 300648.XSHE 星云股份
# 20180202 300649.XSHE 杭州园林
# 20180202 300650.XSHE 太龙照明
# 20180202 300651.XSHE 金陵体育
# 20180202 300652.XSHE 雷迪克
# 20180202 300653.XSHE 正海生物
# 20180202 300654.XSHE 世纪天鸿
# 20180202 300655.XSHE 晶瑞股份
# 20180202 300657.XSHE 弘信电子
# 20180202 300658.XSHE 延江股份
# 20180202 300660.XSHE 江苏雷利
# 20180202 300661.XSHE 圣邦股份
# 20180202 300662.XSHE 科锐国际
# 20180202 300663.XSHE 科蓝软件
# 20180202 300664.XSHE 鹏鹞环保
# 20180202 300665.XSHE 飞鹿股份
# 20180202 300666.XSHE 江丰电子
# 20180202 300667.XSHE 必创科技
# 20180202 300668.XSHE 杰恩设计
# 20180202 300669.XSHE 沪宁股份
# 20180202 300670.XSHE 大烨智能
# 20180202 300671.XSHE 富满电子
# 20180202 300672.XSHE 国科微
# 20180202 300673.XSHE 佩蒂股份
# 20180202 300675.XSHE 建科院
# 20180202 300676.XSHE 华大基因
# 20180202 300677.XSHE 英科医疗
# 20180202 300678.XSHE 中科信息
# 20180202 300679.XSHE 电连技术
# 20180202 300681.XSHE 英搏尔
# 20180202 300683.XSHE 海特生物
# 20180202 300684.XSHE 中石科技
# 20180202 300685.XSHE 艾德生物
# 20180202 300686.XSHE 智动力
# 20180202 300687.XSHE 赛意信息
# 20180202 300688.XSHE 创业黑马
# 20180202 300689.XSHE 澄天伟业
# 20180202 300690.XSHE 双一科技
# 20180202 300691.XSHE 联合光电
# 20180202 300692.XSHE 中环环保
# 20180202 300693.XSHE 盛弘股份
# ...
# 20180202 600889.XSHG 南京化纤
# 20180202 600890.XSHG 中房股份
# 20180202 600891.XSHG 秋林集团
# 20180202 600892.XSHG 大晟文化
# 20180202 600893.XSHG 航发动力
# 20180202 600894.XSHG 广日股份
# 20180202 600895.XSHG 张江高科
# 20180202 600896.XSHG 览海投资
# 20180202 600897.XSHG 厦门空港
# 20180202 600898.XSHG 国美通讯
# 20180202 600900.XSHG 长江电力
# 20180202 600903.XSHG 贵州燃气
# 20180202 600908.XSHG 无锡银行
# 20180202 600909.XSHG 华安证券
# 20180202 600917.XSHG 重庆燃气
# 20180202 600919.XSHG 江苏银行
# 20180202 600926.XSHG 杭州银行
# 20180202 600933.XSHG 爱柯迪
# 20180202 600936.XSHG 广西广电
# 20180202 600939.XSHG 重庆建工
# 20180202 600958.XSHG 东方证券
# 20180202 600961.XSHG 株冶集团
# 20180202 600962.XSHG 国投中鲁
# 20180202 600963.XSHG 岳阳林纸
# 20180202 600965.XSHG 福成股份
# 20180202 600966.XSHG 博汇纸业
# 20180202 600967.XSHG 内蒙一机
# 20180202 600969.XSHG 郴电国际
# 20180202 600970.XSHG 中材国际
# 20180202 600971.XSHG 恒源煤电
# 20180202 600973.XSHG 宝胜股份
# 20180202 600975.XSHG 新五丰
# 20180202 600976.XSHG 健民集团
# 20180202 600977.XSHG 中国电影
# 20180202 600978.XSHG 宜华生活
# 20180202 600979.XSHG 广安爱众
# 20180202 600980.XSHG 北矿科技
# 20180202 600981.XSHG 汇鸿集团
# 20180202 600982.XSHG 宁波热电
# 20180202 600983.XSHG 惠而浦
# 20180202 600984.XSHG 建设机械
# 20180202 600985.XSHG 雷鸣科化
# 20180202 600986.XSHG 科达股份
# 20180202 600987.XSHG 航民股份
# 20180202 600988.XSHG 赤峰黄金
# 20180202 600990.XSHG 四创电子
# 20180202 600992.XSHG 贵绳股份
# 20180202 600993.XSHG 马应龙
# 20180202 600995.XSHG 文山电力
# 20180202 600996.XSHG 贵广网络
# 20180202 600997.XSHG 开滦股份
# 20180202 600998.XSHG 九州通
# 20180202 600999.XSHG 招商证券
# 20180202 601000.XSHG 唐山港
# 20180202 601001.XSHG 大同煤业
# 20180202 601002.XSHG 晋亿实业
# 20180202 601003.XSHG 柳钢股份
# 20180202 601005.XSHG *ST重钢
# 20180202 601006.XSHG 大秦铁路
# 20180202 601007.XSHG 金陵饭店
# 20180202 601008.XSHG 连云港
# 20180202 601009.XSHG 南京银行
# 20180202 601010.XSHG 文峰股份
# 20180202 601011.XSHG 宝泰隆
# 20180202 601012.XSHG 隆基股份
# 20180202 601015.XSHG 陕西黑猫
# 20180202 601016.XSHG 节能风电
# 20180202 601018.XSHG 宁波港
# 20180202 601019.XSHG 山东出版
# 20180202 601020.XSHG 华钰矿业
# 20180202 601021.XSHG 春秋航空
# 20180202 601028.XSHG 玉龙股份
# 20180202 601038.XSHG 一拖股份
# 20180202 601058.XSHG 赛轮金宇
# 20180202 601069.XSHG 西部黄金
# 20180202 601086.XSHG 国芳集团
# 20180202 601088.XSHG 中国神华
# 20180202 601098.XSHG 中南传媒
# 20180202 601099.XSHG 太平洋
# 20180202 601100.XSHG 恒立液压
# 20180202 601101.XSHG 昊华能源
# 20180202 601106.XSHG *ST一重
# 20180202 601107.XSHG 四川成渝
# 20180202 601108.XSHG 财通证券
# 20180202 601111.XSHG 中国国航
# 20180202 601113.XSHG 华鼎股份
# 20180202 601116.XSHG 三江购物
# 20180202 601117.XSHG 中国化学
# 20180202 601118.XSHG 海南橡胶
# 20180202 601126.XSHG 四方股份
# 20180202 601127.XSHG 小康股份
# 20180202 601128.XSHG 常熟银行
# 20180202 601137.XSHG 博威合金
# 20180202 601139.XSHG 深圳燃气
# 20180202 601155.XSHG 新城控股
# 20180202 601158.XSHG 重庆水务
# 20180202 601163.XSHG 三角轮胎
# 20180202 601166.XSHG 兴业银行
# 20180202 601168.XSHG 西部矿业
# 20180202 601169.XSHG 北京银行
# 20180202 601177.XSHG 杭齿前进
# 20180202 601179.XSHG 中国西电
# 20180202 601186.XSHG 中国铁建
# 20180202 601188.XSHG 龙江交通
# 20180202 601198.XSHG 东兴证券
# 20180202 601199.XSHG 江南水务
# 20180202 601200.XSHG 上海环境
# 20180202 601208.XSHG 东材科技
# 20180202 601211.XSHG 国泰君安
# 20180202 601212.XSHG 白银有色
# 20180202 601218.XSHG 吉鑫科技
# 20180202 601222.XSHG 林洋能源
# 20180202 601225.XSHG 陕西煤业
# 20180202 601226.XSHG 华电重工
# 20180202 601228.XSHG 广州港
# 20180202 601229.XSHG 上海银行
# 20180202 601231.XSHG 环旭电子
# 20180202 601233.XSHG 桐昆股份
# 20180202 601238.XSHG 广汽集团
# 20180202 601258.XSHG 庞大集团
# 20180202 601288.XSHG 农业银行
# 20180202 601311.XSHG 骆驼股份
# 20180202 601313.XSHG 江南嘉捷
# 20180202 601318.XSHG 中国平安
# 20180202 601326.XSHG 秦港股份
# 20180202 601328.XSHG 交通银行
# 20180202 601333.XSHG 广深铁路
# 20180202 601336.XSHG 新华保险
# 20180202 601339.XSHG 百隆东方
# 20180202 601366.XSHG 利群股份
# 20180202 601368.XSHG 绿城水务
# 20180202 601375.XSHG 中原证券
# 20180202 601377.XSHG 兴业证券
# 20180202 601388.XSHG 怡球资源
# 20180202 601390.XSHG 中国中铁
# 20180202 601398.XSHG 工商银行
# 20180202 601500.XSHG 通用股份
# 20180202 601515.XSHG 东风股份
# 20180202 601518.XSHG 吉林高速
# 20180202 601519.XSHG *ST智慧
# 20180202 601555.XSHG 东吴证券
# 20180202 601558.XSHG *ST锐电
# 20180202 601566.XSHG 九牧王
# 20180202 601567.XSHG 三星医疗
# 20180202 601579.XSHG 会稽山
# 20180202 601588.XSHG 北辰实业
# 20180202 601595.XSHG 上海电影
# 20180202 601599.XSHG 鹿港文化
# 20180202 601601.XSHG 中国太保
# 20180202 601607.XSHG 上海医药
# 20180202 601608.XSHG 中信重工
# 20180202 601611.XSHG 中国核建
# 20180202 601616.XSHG 广电电气
# 20180202 601618.XSHG 中国中冶
# 20180202 601628.XSHG 中国人寿
# 20180202 601633.XSHG 长城汽车
# 20180202 601636.XSHG 旗滨集团
# 20180202 601666.XSHG 平煤股份
# 20180202 601668.XSHG 中国建筑
# 20180202 601669.XSHG 中国电建
# 20180202 601677.XSHG 明泰铝业
# 20180202 601678.XSHG 滨化股份
# 20180202 601688.XSHG 华泰证券
# 20180202 601689.XSHG 拓普集团
# 20180202 601699.XSHG 潞安环能
# 20180202 601700.XSHG 风范股份
# 20180202 601717.XSHG 郑煤机
# 20180202 601718.XSHG 际华集团
# 20180202 601727.XSHG 上海电气
# 20180202 601766.XSHG 中国中车
# 20180202 601777.XSHG 力帆股份
# 20180202 601788.XSHG 光大证券
# 20180202 601789.XSHG 宁波建工
# 20180202 601798.XSHG 蓝科高新
# 20180202 601799.XSHG 星宇股份
# 20180202 601800.XSHG 中国交建
# 20180202 601801.XSHG 皖新传媒
# 20180202 601808.XSHG 中海油服
# 20180202 601811.XSHG 新华文轩
# 20180202 601818.XSHG 光大银行
# 20180202 601828.XSHG 美凯龙
# 20180202 601838.XSHG 成都银行
# 20180202 601857.XSHG 中国石油
# 20180202 601858.XSHG 中国科传
# 20180202 601866.XSHG 中远海发
# 20180202 601872.XSHG 招商轮船
# 20180202 601877.XSHG 正泰电器
# 20180202 601878.XSHG 浙商证券
# 20180202 601880.XSHG 大连港
# 20180202 601881.XSHG 中国银河
# 20180202 601882.XSHG 海天精工
# 20180202 601886.XSHG 江河集团
# 20180202 601888.XSHG 中国国旅
# 20180202 601890.XSHG 亚星锚链
# 20180202 601898.XSHG 中煤能源
# 20180202 601899.XSHG 紫金矿业
# 20180202 601900.XSHG 南方传媒
# 20180202 601901.XSHG 方正证券
# 20180202 601908.XSHG 京运通
# 20180202 601918.XSHG 新集能源
# 20180202 601919.XSHG 中远海控
# 20180202 601928.XSHG 凤凰传媒
# 20180202 601929.XSHG 吉视传媒
# 20180202 601933.XSHG 永辉超市
# 20180202 601939.XSHG 建设银行
# 20180202 601949.XSHG 中国出版
# 20180202 601952.XSHG 苏垦农发
# 20180202 601958.XSHG 金钼股份
# 20180202 601965.XSHG 中国汽研
# 20180202 601966.XSHG 玲珑轮胎
# 20180202 601968.XSHG 宝钢包装
# 20180202 601969.XSHG 海南矿业
# 20180202 601985.XSHG 中国核电
# 20180202 601988.XSHG 中国银行
# 20180202 601989.XSHG 中国重工
# 20180202 601991.XSHG 大唐发电
# 20180202 601992.XSHG 金隅集团
# 20180202 601996.XSHG 丰林集团
# 20180202 601997.XSHG 贵阳银行
# 20180202 601998.XSHG 中信银行
# 20180202 601999.XSHG 出版传媒
# 20180202 603000.XSHG 人民网
# 20180202 603001.XSHG 奥康国际
# 20180202 603002.XSHG 宏昌电子
# 20180202 603003.XSHG 龙宇燃油
# 20180202 603005.XSHG 晶方科技
# 20180202 603006.XSHG 联明股份
# 20180202 603007.XSHG 花王股份
# 20180202 603008.XSHG 喜临门
# 20180202 603009.XSHG 北特科技
# 20180202 603010.XSHG 万盛股份
# 20180202 603011.XSHG 合锻智能
# 20180202 603012.XSHG 创力集团
# 20180202 603015.XSHG 弘讯科技
# 20180202 603016.XSHG 新宏泰
# 20180202 603017.XSHG 中衡设计
# 20180202 603018.XSHG 中设集团
# 20180202 603019.XSHG 中科曙光
# 20180202 603020.XSHG 爱普股份
# 20180202 603022.XSHG 新通联
# 20180202 603023.XSHG 威帝股份
# 20180202 603025.XSHG 大豪科技
# 20180202 603026.XSHG 石大胜华
# 20180202 603027.XSHG 千禾味业
# 20180202 603029.XSHG 天鹅股份
# 20180202 603030.XSHG 全筑股份
# 20180202 603031.XSHG 安德利
# 20180202 603035.XSHG 常熟汽饰
# 20180202 603036.XSHG 如通股份
# 20180202 603037.XSHG 凯众股份
# 20180202 603038.XSHG 华立股份
# 20180202 603039.XSHG 泛微网络
# 20180202 603040.XSHG 新坐标
# 20180202 603041.XSHG 美思德
# 20180202 603042.XSHG 华脉科技
# 20180202 603043.XSHG 广州酒家
# 20180202 603050.XSHG 科林电气
# 20180202 603055.XSHG 台华新材
# 20180202 603056.XSHG 德邦股份
# 20180202 603060.XSHG 国检集团
# 20180202 603063.XSHG 禾望电气
# 20180202 603066.XSHG 音飞储存
# 20180202 603067.XSHG 振华股份
# 20180202 603069.XSHG 海汽集团
# 20180202 603076.XSHG 乐惠国际
# 20180202 603077.XSHG 和邦生物
# 20180202 603078.XSHG 江化微
# 20180202 603080.XSHG 新疆火炬
# 20180202 603081.XSHG 大丰实业
# 20180202 603083.XSHG 剑桥科技
# 20180202 603085.XSHG 天成自控
# 20180202 603086.XSHG 先达股份
# 20180202 603088.XSHG 宁波精达
# 20180202 603089.XSHG 正裕工业
# 20180202 603090.XSHG 宏盛股份
# 20180202 603096.XSHG 新经典
# 20180202 603098.XSHG 森特股份
# 20180202 603099.XSHG 长白山
# 20180202 603100.XSHG 川仪股份
# 20180202 603101.XSHG 汇嘉时代
# 20180202 603103.XSHG 横店影视
# 20180202 603106.XSHG 恒银金融
# 20180202 603108.XSHG 润达医疗
# 20180202 603110.XSHG 东方材料
# 20180202 603111.XSHG 康尼机电
# 20180202 603113.XSHG 金能科技
# 20180202 603116.XSHG 红蜻蜓
# 20180202 603117.XSHG 万林股份
# 20180202 603118.XSHG 共进股份
# 20180202 603123.XSHG 翠微股份
# 20180202 603126.XSHG 中材节能
# 20180202 603127.XSHG 昭衍新药
# 20180202 603128.XSHG 华贸物流
# 20180202 603129.XSHG 春风动力
# 20180202 603131.XSHG 上海沪工
# 20180202 603133.XSHG 碳元科技
# 20180202 603136.XSHG 天目湖
# 20180202 603138.XSHG 海量数据
# 20180202 603139.XSHG 康惠制药
# 20180202 603157.XSHG 拉夏贝尔
# 20180202 603158.XSHG 腾龙股份
# 20180202 603159.XSHG 上海亚虹
# 20180202 603160.XSHG 汇顶科技
# 20180202 603161.XSHG 科华控股
# 20180202 603165.XSHG 荣晟环保
# 20180202 603166.XSHG 福达股份
# 20180202 603167.XSHG 渤海轮渡
# 20180202 603168.XSHG 莎普爱思
# 20180202 603169.XSHG 兰石重装
# 20180202 603177.XSHG 德创环保
# 20180202 603178.XSHG 圣龙股份
# 20180202 603179.XSHG 新泉股份
# 20180202 603180.XSHG 金牌厨柜
# 20180202 603181.XSHG 皇马科技
# 20180202 603183.XSHG 建研院
# 20180202 603186.XSHG 华正新材
# 20180202 603188.XSHG 亚邦股份
# 20180202 603189.XSHG 网达软件
# 20180202 603196.XSHG 日播时尚
# 20180202 603197.XSHG 保隆科技
# 20180202 603198.XSHG 迎驾贡酒
# 20180202 603199.XSHG 九华旅游
# 20180202 603200.XSHG 上海洗霸
# 20180202 603203.XSHG 快克股份
# 20180202 603208.XSHG 江山欧派
# 20180202 603218.XSHG 日月股份
# 20180202 603222.XSHG 济民制药
# 20180202 603223.XSHG 恒通股份
# 20180202 603225.XSHG 新凤鸣
# 20180202 603226.XSHG 菲林格尔
# 20180202 603227.XSHG 雪峰科技
# 20180202 603228.XSHG 景旺电子
# 20180202 603229.XSHG 奥翔药业
# 20180202 603232.XSHG 格尔软件
# 20180202 603233.XSHG 大参林
# 20180202 603238.XSHG 诺邦股份
# 20180202 603239.XSHG 浙江仙通
# 20180202 603258.XSHG 电魂网络
# 20180202 603260.XSHG 合盛硅业
# 20180202 603266.XSHG 天龙股份
# 20180202 603268.XSHG 松发股份
# 20180202 603269.XSHG 海鸥股份
# 20180202 603277.XSHG 银都股份
# 20180202 603278.XSHG 大业股份
# 20180202 603283.XSHG 赛腾股份
# 20180202 603286.XSHG 日盈电子
# 20180202 603288.XSHG 海天味业
# 20180202 603289.XSHG 泰瑞机器
# 20180202 603298.XSHG 杭叉集团
# 20180202 603299.XSHG 井神股份
# 20180202 603300.XSHG 华铁科技
# 20180202 603303.XSHG 得邦照明
# 20180202 603305.XSHG 旭升股份
# 20180202 603306.XSHG 华懋科技
# 20180202 603308.XSHG 应流股份
# 20180202 603311.XSHG 金海环境
# 20180202 603313.XSHG 梦百合
# 20180202 603315.XSHG 福鞍股份
# 20180202 603316.XSHG 诚邦股份
# 20180202 603318.XSHG 派思股份
# 20180202 603319.XSHG 湘油泵
# 20180202 603320.XSHG 迪贝电气
# 20180202 603321.XSHG 梅轮电梯
# 20180202 603322.XSHG 超讯通信
# 20180202 603323.XSHG 吴江银行
# 20180202 603326.XSHG 我乐家居
# 20180202 603328.XSHG 依顿电子
# 20180202 603329.XSHG 上海雅仕
# 20180202 603330.XSHG 上海天洋
# 20180202 603331.XSHG 百达精工
# 20180202 603333.XSHG 明星电缆
# 20180202 603335.XSHG 迪生力
# 20180202 603336.XSHG 宏辉果蔬
# 20180202 603337.XSHG 杰克股份
# 20180202 603338.XSHG 浙江鼎力
# 20180202 603339.XSHG 四方冷链
# 20180202 603345.XSHG 安井食品
# 20180202 603355.XSHG 莱克电气
# 20180202 603356.XSHG 华菱精工
# 20180202 603357.XSHG 设计总院
# 20180202 603358.XSHG 华达科技
# 20180202 603359.XSHG 东珠景观
# 20180202 603360.XSHG 百傲化学
# 20180202 603363.XSHG 傲农生物
# 20180202 603365.XSHG 水星家纺
# 20180202 603366.XSHG 日出东方
# 20180202 603367.XSHG 辰欣药业
# 20180202 603368.XSHG 柳州医药
# 20180202 603369.XSHG 今世缘
# 20180202 603377.XSHG 东方时尚
# 20180202 603378.XSHG 亚士创能
# 20180202 603380.XSHG 易德龙
# 20180202 603383.XSHG 顶点软件
# 20180202 603385.XSHG 惠达卫浴
# 20180202 603386.XSHG 广东骏亚
# 20180202 603387.XSHG 基蛋生物
# 20180202 603388.XSHG 元成股份
# 20180202 603389.XSHG 亚振家居
# 20180202 603393.XSHG 新天然气
# 20180202 603396.XSHG 金辰股份
# 20180202 603398.XSHG 邦宝益智
# 20180202 603399.XSHG 新华龙
# 20180202 603416.XSHG 信捷电气
# 20180202 603421.XSHG 鼎信通讯
# 20180202 603444.XSHG 吉比特
# 20180202 603456.XSHG 九洲药业
# 20180202 603458.XSHG 勘设股份
# 20180202 603477.XSHG 振静股份
# 20180202 603488.XSHG 展鹏科技
# 20180202 603496.XSHG 恒为科技
# 20180202 603499.XSHG 翔港科技
# 20180202 603500.XSHG 祥和实业
# 20180202 603501.XSHG 韦尔股份
# 20180202 603505.XSHG 金石资源
# 20180202 603506.XSHG 南都物业
# 20180202 603507.XSHG 振江股份
# 20180202 603508.XSHG 思维列控
# 20180202 603515.XSHG 欧普照明
# 20180202 603516.XSHG 淳中科技
# 20180202 603517.XSHG 绝味食品
# 20180202 603518.XSHG 维格娜丝
# 20180202 603519.XSHG 立霸股份
# 20180202 603527.XSHG 众源新材
# 20180202 603528.XSHG 多伦科技
# 20180202 603533.XSHG 掌阅科技
# 20180202 603535.XSHG 嘉诚国际
# 20180202 603536.XSHG 惠发股份
# 20180202 603538.XSHG 美诺华
# 20180202 603555.XSHG 贵人鸟
# 20180202 603556.XSHG 海兴电力
# 20180202 603557.XSHG 起步股份
# 20180202 603558.XSHG 健盛集团
# 20180202 603559.XSHG 中通国脉
# 20180202 603566.XSHG 普莱柯
# 20180202 603567.XSHG 珍宝岛
# 20180202 603568.XSHG 伟明环保
# 20180202 603569.XSHG 长久物流
# 20180202 603577.XSHG 汇金通
# 20180202 603578.XSHG 三星新材
# 20180202 603579.XSHG 荣泰健康
# 20180202 603580.XSHG 艾艾精工
# 20180202 603585.XSHG 苏利股份
# 20180202 603586.XSHG 金麒麟
# 20180202 603588.XSHG 高能环境
# 20180202 603589.XSHG 口子窖
# 20180202 603595.XSHG 东尼电子
# 20180202 603599.XSHG 广信股份
# 20180202 603600.XSHG 永艺股份
# 20180202 603601.XSHG 再升科技
# 20180202 603602.XSHG 纵横通信
# 20180202 603605.XSHG 珀莱雅
# 20180202 603606.XSHG 东方电缆
# 20180202 603607.XSHG 京华激光
# 20180202 603608.XSHG 天创时尚
# 20180202 603609.XSHG 禾丰牧业
# 20180202 603611.XSHG 诺力股份
# 20180202 603612.XSHG 索通发展
# 20180202 603615.XSHG 茶花股份
# 20180202 603616.XSHG 韩建河山
# 20180202 603617.XSHG 君禾股份
# 20180202 603618.XSHG 杭电股份
# 20180202 603619.XSHG 中曼石油
# 20180202 603626.XSHG 科森科技
# 20180202 603628.XSHG 清源股份
# 20180202 603630.XSHG 拉芳家化
# 20180202 603633.XSHG 徕木股份
# 20180202 603636.XSHG 南威软件
# 20180202 603637.XSHG 镇海股份
# 20180202 603638.XSHG 艾迪精密
# 20180202 603639.XSHG 海利尔
# 20180202 603648.XSHG 畅联股份
# 20180202 603655.XSHG 朗博科技
# 20180202 603656.XSHG 泰禾光电
# 20180202 603658.XSHG 安图生物
# 20180202 603659.XSHG 璞泰来
# 20180202 603660.XSHG 苏州科达
# 20180202 603661.XSHG 恒林股份
# 20180202 603663.XSHG 三祥新材
# 20180202 603665.XSHG 康隆达
# 20180202 603668.XSHG 天马科技
# 20180202 603669.XSHG 灵康药业
# 20180202 603676.XSHG 卫信康
# 20180202 603677.XSHG 奇精机械
# 20180202 603678.XSHG 火炬电子
# 20180202 603679.XSHG 华体科技
# 20180202 603683.XSHG 晶华新材
# 20180202 603685.XSHG 晨丰科技
# 20180202 603686.XSHG 龙马环卫
# 20180202 603688.XSHG 石英股份
# 20180202 603689.XSHG 皖天然气
# 20180202 603690.XSHG 至纯科技
# 20180202 603696.XSHG 安记食品
# 20180202 603698.XSHG 航天工程
# 20180202 603699.XSHG 纽威股份
# 20180202 603701.XSHG 德宏股份
# 20180202 603703.XSHG 盛洋科技
# 20180202 603707.XSHG 健友股份
# 20180202 603708.XSHG 家家悦
# 20180202 603711.XSHG 香飘飘
# 20180202 603716.XSHG 塞力斯
# 20180202 603717.XSHG 天域生态
# 20180202 603718.XSHG 海利生物
# 20180202 603721.XSHG 中广天择
# 20180202 603722.XSHG 阿科力
# 20180202 603725.XSHG 天安新材
# 20180202 603726.XSHG 朗迪集团
# 20180202 603727.XSHG 博迈科
# 20180202 603728.XSHG 鸣志电器
# 20180202 603729.XSHG 龙韵股份
# 20180202 603737.XSHG 三棵树
# 20180202 603738.XSHG 泰晶科技
# 20180202 603757.XSHG 大元泵业
# 20180202 603766.XSHG 隆鑫通用
# 20180202 603767.XSHG 中马传动
# 20180202 603768.XSHG 常青股份
# 20180202 603776.XSHG 永安行
# 20180202 603777.XSHG 来伊份
# 20180202 603778.XSHG 乾景园林
# 20180202 603779.XSHG 威龙股份
# 20180202 603787.XSHG 新日股份
# 20180202 603788.XSHG 宁波高发
# 20180202 603789.XSHG 星光农机
# 20180202 603797.XSHG 联泰环保
# 20180202 603798.XSHG 康普顿
# 20180202 603799.XSHG 华友钴业
# 20180202 603800.XSHG 道森股份
# 20180202 603801.XSHG 志邦股份
# 20180202 603803.XSHG 瑞斯康达
# 20180202 603806.XSHG 福斯特
# 20180202 603808.XSHG 歌力思
# 20180202 603809.XSHG 豪能股份
# 20180202 603811.XSHG 诚意药业
# 20180202 603813.XSHG 原尚股份
# 20180202 603816.XSHG 顾家家居
# 20180202 603817.XSHG 海峡环保
# 20180202 603818.XSHG 曲美家居
# 20180202 603819.XSHG 神力股份
# 20180202 603823.XSHG 百合花
# 20180202 603825.XSHG 华扬联众
# 20180202 603826.XSHG 坤彩科技
# 20180202 603828.XSHG 柯利达
# 20180202 603829.XSHG 洛凯股份
# 20180202 603833.XSHG 欧派家居
# 20180202 603838.XSHG 四通股份
# 20180202 603839.XSHG 安正时尚
# 20180202 603843.XSHG 正平股份
# 20180202 603848.XSHG 好太太
# 20180202 603855.XSHG 华荣股份
# 20180202 603856.XSHG 东宏股份
# 20180202 603858.XSHG 步长制药
# 20180202 603859.XSHG 能科股份
# 20180202 603860.XSHG 中公高科
# 20180202 603861.XSHG 白云电器
# 20180202 603866.XSHG 桃李面包
# 20180202 603868.XSHG 飞科电器
# 20180202 603869.XSHG 北部湾旅
# 20180202 603877.XSHG 太平鸟
# 20180202 603878.XSHG 武进不锈
# 20180202 603879.XSHG 永悦科技
# 20180202 603880.XSHG 南卫股份
# 20180202 603881.XSHG 数据港
# 20180202 603882.XSHG 金域医学
# 20180202 603883.XSHG 老百姓
# 20180202 603885.XSHG 吉祥航空
# 20180202 603886.XSHG 元祖股份
# 20180202 603888.XSHG 新华网
# 20180202 603889.XSHG 新澳股份
# 20180202 603890.XSHG 春秋电子
# 20180202 603895.XSHG 天永智能
# 20180202 603896.XSHG 寿仙谷
# 20180202 603898.XSHG 好莱客
# 20180202 603899.XSHG 晨光文具
# 20180202 603900.XSHG 莱绅通灵
# 20180202 603901.XSHG 永创智能
# 20180202 603903.XSHG 中持股份
# 20180202 603906.XSHG 龙蟠科技
# 20180202 603908.XSHG 牧高笛
# 20180202 603909.XSHG 合诚股份
# 20180202 603912.XSHG 佳力图
# 20180202 603916.XSHG 苏博特
# 20180202 603917.XSHG 合力科技
# 20180202 603918.XSHG 金桥信息
# 20180202 603919.XSHG 金徽酒
# 20180202 603920.XSHG 世运电路
# 20180202 603922.XSHG 金鸿顺
# 20180202 603926.XSHG 铁流股份
# 20180202 603928.XSHG 兴业股份
# 20180202 603929.XSHG 亚翔集成
# 20180202 603933.XSHG 睿能科技
# 20180202 603936.XSHG 博敏电子
# 20180202 603937.XSHG 丽岛新材
# 20180202 603938.XSHG 三孚股份
# 20180202 603939.XSHG 益丰药房
# 20180202 603955.XSHG 大千生态
# 20180202 603958.XSHG 哈森股份
# 20180202 603959.XSHG 百利科技
# 20180202 603960.XSHG 克来机电
# 20180202 603963.XSHG 大理药业
# 20180202 603966.XSHG 法兰泰克
# 20180202 603968.XSHG 醋化股份
# 20180202 603969.XSHG 银龙股份
# 20180202 603970.XSHG 中农立华
# 20180202 603976.XSHG 正川股份
# 20180202 603977.XSHG 国泰集团
# 20180202 603978.XSHG 深圳新星
# 20180202 603979.XSHG 金诚信
# 20180202 603980.XSHG 吉华集团
# 20180202 603985.XSHG 恒润股份
# 20180202 603987.XSHG 康德莱
# 20180202 603988.XSHG 中电电机
# 20180202 603989.XSHG 艾华集团
# 20180202 603990.XSHG 麦迪科技
# 20180202 603991.XSHG 至正股份
# 20180202 603993.XSHG 洛阳钼业
# 20180202 603996.XSHG 中新科技
# 20180202 603997.XSHG 继峰股份
# 20180202 603998.XSHG 方盛制药
# 20180202 603999.XSHG 读者传媒

# %%
#CCI指标 方差函数模块
def AVEDEV(value,N):
    mean = value/N
    for i in range(1,N):
        mean += REF(value,i)/N
    sum_ = ABS(value-mean)
    for i in range(1,N):
        sum_ += ABS(REF(value,i)-mean)
    
    return sum_/N
M=22
TYP = (H+L+C)/3
CCI = (TYP-MA(TYP,M))/(0.015*AVEDEV(TYP,M))
VCCI = (V-MA(V,M))/(0.015*AVEDEV(V,M))
VC = ((CCI+VCCI)-MA((CCI+VCCI),M))/(0.015*AVEDEV((CCI+VCCI),M))
VV= MA((VC+CCI)/(VC-CCI),M)
print (VCCI,CCI,VC)
f, (ax1,ax2) = plt.subplots(2,1)
ax1.plot(L.series, label="L", linewidth=1,color="red")
ax1.plot(MA(L, 7).series, label="ma7", alpha=0.7)
ax1.plot(MA(H, 11).series, label="ma11", alpha=0.7)
ax1.plot(MA(H, 22).series, label="ma22", alpha=0.7)
ax1.plot(MA(H, 66).series, label="ma66", alpha=0.7)
ax1.set_xlim(66)
ax2.plot(VC.series, label="VC",linewidth=1,color="red")
#ax2.plot(MA(VC,3).series, label="vcci1", alpha=0.7)
#ax2.plot(MA(VC, 4).series, label="vcci2", alpha=0.7)
#ax2.plot(MA(VC, 5).series, label="vcci3", alpha=0.7)
#ax2.plot(MA(VC, 6).series, label="vcci4", alpha=0.7)
#ax2.plot(VV.series, label="VV",linewidth=1, color="green")
#ax2.plot(MA(CCI, 3).series, label="cci1", alpha=0.7)
#ax2.plot(MA(CCI, 4).series, label="cci2", alpha=0.7)
#ax2.plot(MA(CCI, 5).series, label="cci3", alpha=0.7)
#ax2.plot(MA(CCI, 6).series, label="cci4", alpha=0.7)
ax2.set_xlim(-14)
N1=101
N2=-101
N3=101
#buy_signal = CROSS(CCI or VC,N1 or N2)
#sell_signal = CROSS(CCI+VC,N1+N2)
#plt.plot(np.where(buy_signal.series)[0], CCI.series[np.where(buy_signal.series)[0]], "^", label="buy", markersize=12, color="red")
#plt.plot(np.where(sell_signal.series)[0], CCI.series[np.where(sell_signal.series)[0]], "v", label="sell", markersize=12, color="green")
plt.legend(loc="best")
plt.show()
# Out:
# -39.994921715978634 -35.10138468145398 -200.18528230171728
