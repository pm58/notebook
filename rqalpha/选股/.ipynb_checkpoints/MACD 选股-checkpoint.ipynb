# %%
# %load_ext rqalpha

# %%
# %%rqalpha -h
# ""
# Out:
# Usage: ipykernel_launcher.py [OPTIONS]
#
#   Start to run a strategy
#
# Options:
#   -h, --help                      Show this message and exit.
#   -d, --data-bundle-path PATH
#   -f, --strategy-file PATH
#   -s, --start-date DATE
#   -e, --end-date DATE
#   -bm, --benchmark TEXT
#   -mm, --margin-multiplier FLOAT
#   -a, --account TEXT...           set account type with starting cash
#   --position TEXT                 set init position
#   -fq, --frequency [1d|1m|tick]
#   -rt, --run-type [b|p|r]
#   --resume
#   --source-code TEXT
#   -l, --log-level [verbose|debug|info|error|none]
#   --disable-user-system-log       disable user system log stdout
#   --disable-user-log              disable user log stdout
#   --logger TEXT...                config logger, e.g. --logger system_log
#                                   debug
#   --locale [cn|en]
#   --extra-vars TEXT               override context vars
#   --enable-profiler               add line profiler to profile your strategy
#   --dividend-reinvestment         enable dividend reinvestment
#   --config TEXT                   config file path
#   -mc, --mod-config TEXT...       mod extra config
#   --stock-t1 / --no-stock-t1      [sys_accounts] enable/disable stock T+1
#   --signal                        [sys_simulation] exclude match engine
#   -sp, --slippage FLOAT           [sys_simulation] set slippage
#   -cm, --commission-multiplier FLOAT
#                                   [sys_simulation] set commission multiplier
#   -me, --match-engine [current_bar|next_bar|last|best_own|best_counterparty]
#                                   [Deprecated][sys_simulation] set matching
#                                   type
#   -mt, --matching-type [current_bar|next_bar|last|best_own|best_counterparty]
#                                   [sys_simulation] set matching type
#   --progress                      [sys_progress]show progress bar
#   --no-short-stock / --short-stock
#                                   [sys_risk] enable stock shorting
#   --report PATH                   [sys_analyser] save report
#   -o, --output-file PATH          [sys_analyser] output result pickle file
#   -p, --plot / --no-plot          [sys_analyser] plot result
#   --plot-save TEXT                [sys_analyser] save plot to file

# %%
config = {
  "base": {
    "set_start_date": "2018-01-01",
    "set_end_date": "2018-11-27",
    "start_date": "2018-01-01",
    "end_date": "2018-11-27",
    "benchmark": "000001.XSHG",
    "accounts": {
        "stock": 100000
    }
  },
  "extra": {
    "log_level": "info",
  },
  "mod": {
    "sys_analyser": {
      "enabled": True,
      "plot": True,
    },
  }
}
from rqalpha.api import *
from rqalpha import run_func
from funcat import * #FUNCAT的同花顺/通达信指标模块：和：&，或：|，其他基本相同。可以使用指标选股！！！
from tushare import * #TUSHARE数据连接更新。
from rqalpha import * #RQALPHA本地数据连接，通过 rqalpha update_bundle 8点后更新全部数据库
import time
import datetime #读取/设定数据库时间区域，当前股票，选股时间段。 

#set_start_date("20180112") #设置观察日期
S("000001.XSHG")  # 设置当前关注股票
T("2018-11-27")   # 设置当前观察日期

# %%
######       tushare    #######

from funcat.data.tushare_backend import TushareDataBackend
from funcat.data.rqalpha_data_backend import RQAlphaDataBackend
backend = "tushare"  #设定数据库连接：rqalpha   tushare
if backend == "rqalpha":
    set_data_backend(RQAlphaDataBackend("~/.rqalpha/bundle"))
elif backend == "tushare":
    set_data_backend(TushareDataBackend())
from matplotlib import rcParams
import matplotlib.pyplot as plt
import numpy as np
np.seterr(all='ignore')
rcParams['figure.figsize'] = (20, 20)
DIFF = MA(L,12) - MA(L,26);
DEA  = MA(DIFF,9);
MACD = 1.618*(DIFF-DEA);
MACDMID = (DIFF-DEA)/1.618
OCHL = ((H+L)*(H-L)-(O+C)*(H-L))*MA(H,26)
ZERO = (C-O)*(H-L)*(O-C)*(L-H)
#ax = plt.subplot()
f, (ax1,ax2,ax3,ax4) = plt.subplots(4,1)
buy_signal = (CROSS(MACD, MACDMID) and CROSS(MACD,DIFF)) and DIFF<(MACDMID>0)>DEA #or CROSS(MACD,DIFF)
sell_signal = (CROSS(DIFF,MACDMID) or CROSS(DEA,DIFF)) and DIFF>MACDMID<MACD #or CROSS(MACDMID,MACD)
ax3.plot(H.series, label="H")
ax3.plot(L.series, label="L")
ax3.plot(C.series, label="C")
ax3.plot(O.series, label="O")
#ax3.set_xlim(0)
ax1.plot(OCHL.series, label="OCHL")
ax1.plot(ZERO.series, label="ZERO")
ax2.plot(ZERO.series, label="ZERO")
ax4.plot(MACDMID.series, label="MACDMID")
ax4.plot(MACD.series, label="MACD")
ax4.plot(DIFF.series, label="DIFF")
ax4.plot(DEA.series, label="DEA")
#ax4.plot(ZERO.series, label="ZERO")
ax4.set_xlim(0)
plt.plot(np.where(buy_signal.series)[0], MACD.series[np.where(buy_signal.series)[0]], "^", label="buy", markersize=12, color="red")
plt.plot(np.where(sell_signal.series)[0], MACD.series[np.where(sell_signal.series)[0]], "v", label="sell", markersize=12, color="green")
plt.legend(loc="best")
plt.show()

# %%
######       rqalpha    #######

from funcat.data.tushare_backend import TushareDataBackend
from funcat.data.rqalpha_data_backend import RQAlphaDataBackend
backend = "rqalpha"  #设定数据库连接：rqalpha   tushare
if backend == "rqalpha":
    set_data_backend(RQAlphaDataBackend("~/.rqalpha/bundle"))
elif backend == "tushare":
    set_data_backend(TushareDataBackend())    
from matplotlib import rcParams
import matplotlib.pyplot as plt
import numpy as np
np.seterr(all='ignore')
rcParams['figure.figsize'] = (20, 15)
DIFF = MA(L,12) - MA(L,26);
DEA  = MA(DIFF,9);
MACD = 1.618*(DIFF-DEA);
MACDMID = (DIFF-DEA)/1.618
OCHL = ((H+L)*(H-L)-(O+C)*(H-L))*MA(H,26)
ZERO = (C-O)*(H-L)*(O-C)*(L-H)
f, (ax1,ax2,ax3,ax4) = plt.subplots(4,1)
buy_signal = (CROSS(MACD, MACDMID) and CROSS(MACD,DIFF)) and DIFF<(MACDMID>0)>DEA #or CROSS(MACD,DIFF)
sell_signal = (CROSS(DIFF,MACDMID) or CROSS(DEA,DIFF)) and DIFF>MACDMID<MACD #or CROSS(MACDMID,MACD)
ax3.plot(H.series, label="H")
ax3.plot(L.series, label="L")
ax3.plot(C.series, label="C")
ax3.plot(O.series, label="O")
ax1.plot(OCHL.series, label="OCHL")
ax1.plot(ZERO.series, label="ZERO")
ax2.plot(ZERO.series, label="ZERO")
ax4.plot(MACDMID.series, label="MACDMID")
ax4.plot(MACD.series, label="MACD")
ax4.plot(DIFF.series, label="DIFF")
ax4.plot(DEA.series, label="DEA")
ax4.set_xlim(0)
plt.plot(np.where(buy_signal.series)[0], MACD.series[np.where(buy_signal.series)[0]], "^", label="buy", markersize=12, color="red")
plt.plot(np.where(sell_signal.series)[0], MACD.series[np.where(sell_signal.series)[0]], "v", label="sell", markersize=12, color="green")
plt.legend(loc="best")
plt.show()

# %%
#MACD选股！rqalpha数据库

from matplotlib import rcParams
import matplotlib.pyplot as plt
import numpy as np
np.seterr(all='ignore')
rcParams['figure.figsize'] = (20, 20)

from funcat import * #FUNCAT的同花顺/通达信指标模块：和：&，或：|，其他基本相同。可以使用指标选股！！！
from tushare import * #TUSHARE数据连接更新。
from rqalpha import * #RQALPHA本地数据连接，通过 rqalpha update_bundle 8点后更新全部数据库

import time
import datetime #读取/设定数据库时间区域，当前股票，选股时间段。 

n1 = (time.strftime("20%y-%m-%d"))## 20yy-mm-dd格式，输出当日日期
print ("《设定测试》读取当日时间格式：n1",n1) #当日时间格式：yyyy-mm-dd
n2 = (time.strftime("20%y%m%d"))## 20yymmdd格式，输出当日日期
print ("《设定测试》读取当日时间格式：n2",n2) #当日时间格式：yyyymmdd
def getYesterday(): 
    today=datetime.date.today() 
    oneday=datetime.timedelta(days=1) 
    yesterday=today-oneday  
    return yesterday
n3 = (getYesterday())# 输出前二天日期
print ("《设定测试》读取前二日时间格式：n3",n3) #前日时间格式：yyyy-mm-dd
i = datetime.datetime.now()#当前日期

n4 = ("%s%s%s" % (i.year, i.month, i.day) )
print ("《设定测试》读取当日时间格式：n4",n4) #当日时间格式：yyyymmdd

n5 = ("%s" % i.isoformat() )
print ("《设定测试》读取当日时间格式：n5",n5) #当日时间格式：yyyy-mm-dd:...

n8="20180201"#开始时间
print ("《设定测试》手动设定选股开始时间格式：n8",n8)

n9="20180209"#结束时间
print ("《设定测试》手动设定选股结束时间格式：n9",n9)

def getYesterday(): 
    today=datetime.date.today() 
    oneday=datetime.timedelta(days=300) 
    yesterday=today-oneday  
    return yesterday
n10 = (getYesterday())# 输出前200天日期
#n10="20170101"#设定起始时间
print ("《设定测试》自动设定数据起始设定前推200天：n10",n10)

x1="000001.XSHG" #用rqalpha本地数据需要代码后缀！！！！XSHE=深圳，XSHG=上海
print ("《设定测试》设定股票代码",x1)

x2="002267.XSHE"

from funcat.data.tushare_backend import TushareDataBackend
from funcat.data.rqalpha_data_backend import RQAlphaDataBackend
backend = "rqalpha"  #设定数据库连接：rqalpha   tushare
if backend == "rqalpha":
    set_data_backend(RQAlphaDataBackend("~/.rqalpha/bundle"))
elif backend == "tushare":
    set_data_backend(TushareDataBackend())
set_start_date(n10)

#S(x2)  # 设置当前关注股票
T(n3)   # 设置当前观察日期

print ("《数据测试》打印 开盘 最高 最低 收盘 成交量",O, H, L, C, V)  # 打印 Open High Low Close
print ("《数据测试》当天涨幅",C / C[1] - 1)  # 当天涨幅
print ("《数据测试》打印60日均线",MA(C, 60))  # 打印60日均线
print ("《数据测试》判断收盘价是否大于60日均线",C > MA(C, 60))  # 判断收盘价是否大于60日均线
print ("《数据测试》30日最高价",HHV(H, 30))  # 30日最高价
print ("《数据测试》最近30日，收盘价 Close 大于60日均线的天数",COUNT(C > MA(C, 60), 30))  # 最近30日，收盘价 Close 大于60日均线的天数
print ("《数据测试》10日均线上穿",CROSS(MA(C, 10), MA(C, 20)))  # 10日均线上穿
print ("《数据测试》最近10天收阳线的天数",COUNT(C > O, 10))  # 最近10天收阳线的天数
print ("《数据测试》最近60天K线实体的最高价",HHV(MAX(O, C), 60))  # 最近60天K线实体的最高价
print ("《数据测试》5日均线上穿10日均线",CROSS(MA(C, 5), MA(C, 10)))  # 5日均线上穿10日均线

# MACD 交易系统

DIFF = MA(L,12) - MA(L,26);
DEA  = MA(DIFF,9);
MACD = 1.618*(DIFF-DEA);
MACDMID = (DIFF-DEA)/1.618
OCHL = ((H+L)*(H-L)-(O+C)*(H-L))*MA(H,26)
ZERO = (C-O)*(H-L)*(O-C)*(L-H)

#ax = plt.subplot()
f, (ax1,ax2,ax3,ax4) = plt.subplots(4,1)

buy_signal = (CROSS(MACD, MACDMID) and CROSS(MACD,DIFF)) and DIFF<(MACDMID>0)>DEA #or CROSS(MACD,DIFF)
sell_signal = (CROSS(DIFF,MACDMID) or CROSS(DEA,DIFF)) and DIFF>MACDMID<MACD #or CROSS(MACDMID,MACD)

ax3.plot(H.series, label="H")
ax3.plot(L.series, label="L")
ax3.plot(C.series, label="C")
ax3.plot(O.series, label="O")
#ax3.set_xlim(0)

ax1.plot(OCHL.series, label="OCHL")
ax1.plot(ZERO.series, label="ZERO")

ax2.plot(ZERO.series, label="ZERO")

ax4.plot(MACDMID.series, label="MACDMID")
ax4.plot(MACD.series, label="MACD")
ax4.plot(DIFF.series, label="DIFF")
ax4.plot(DEA.series, label="DEA")
ax4.plot(ZERO.series, label="ZERO")

ax4.set_xlim(0)

plt.plot(np.where(buy_signal.series)[0], MACD.series[np.where(buy_signal.series)[0]], "^", label="buy", markersize=12, color="red")
plt.plot(np.where(sell_signal.series)[0], MACD.series[np.where(sell_signal.series)[0]], "v", label="sell", markersize=12, color="green")

plt.legend(loc="best")
plt.show()
# Out:
# 《设定测试》读取当日时间格式：n1 2018-11-28
# 《设定测试》读取当日时间格式：n2 20181128
# 《设定测试》读取前二日时间格式：n3 2018-11-27
# 《设定测试》读取当日时间格式：n4 20181128
# 《设定测试》读取当日时间格式：n5 2018-11-28T10:20:52.737457
# 《设定测试》手动设定选股开始时间格式：n8 20180201
# 《设定测试》手动设定选股结束时间格式：n9 20180209
# 《设定测试》自动设定数据起始设定前推200天：n10 2018-02-01
# 《设定测试》设定股票代码 000001.XSHG
# 《数据测试》打印 开盘 最高 最低 收盘 成交量 2585.83 2592.54 2566.17 2574.68 12365843600.0
# 《数据测试》当天涨幅 -0.00043869695357967586
# 《数据测试》打印60日均线 2661.809666666666
# 《数据测试》判断收盘价是否大于60日均线 False
# 《数据测试》30日最高价 2703.51
# 《数据测试》最近30日，收盘价 Close 大于60日均线的天数 2
# 《数据测试》10日均线上穿 False
# 《数据测试》最近10天收阳线的天数 4
# 《数据测试》最近60天K线实体的最高价 2821.35
# 《数据测试》5日均线上穿10日均线 False

# %%
DIFF = (MA(L,12) - MA(L,26))
DEA  = (MA((MA(L,12) - MA(L,26)),9))
MACD = (2*((MA(L,12) - MA(L,26))-(MA((MA(L,12) - MA(L,26)),9))))
MACDMID = (((MA(L,12) - MA(L,26))-(MA((MA(L,12) - MA(L,26)),9)))/3)

CROSS((2*((MA(L,12) - MA(L,26))-(MA((MA(L,12) - MA(L,26)),9)))), (((MA(L,12) - MA(L,26))-(MA((MA(L,12) - MA(L,26)),9)))/3))


print ("《RQALPHA本地化开始选股》读取开始时间：==》n5",n5) 
# 选股MACD  OK!!!


select(
    lambda : CROSS((2*((MA(L,12) - MA(L,26))-(MA((MA(L,12) - MA(L,26)),9)))), (((MA(L,12) - MA(L,26))-(MA((MA(L,12) - MA(L,26)),9)))/3))

 ,
    start_date=(n3), end_date=(n2),
)

print ("《结束选股》读取结束时间：==》n5",n5)
# Out:
# 《RQALPHA本地化开始选股》读取开始时间：==》n5 2018-11-28T10:20:52.737457
# lambda : CROSS((2*((MA(L,12) - MA(L,26))-(MA((MA(L,12) - MA(L,26)),9)))), (((MA(L,12) - MA(L,26))-(MA((MA(L,12) - MA(L,26)),9)))/3))
# [20181128]
# No data for 000003.XSHE
# No data for 000013.XSHE
# No data for 000015.XSHE
# No data for 000047.XSHE
# No data for 000405.XSHE
# No data for 000412.XSHE
# No data for 000508.XSHE
# No data for 000542.XSHE
# No data for 000556.XSHE
# No data for 000588.XSHE
# No data for 000621.XSHE
# No data for 000653.XSHE
# No data for 000658.XSHE
# No data for 000660.XSHE
# No data for 000675.XSHE
# No data for 000689.XSHE
# No data for 000730.XSHE
# No data for 002257.XSHE
# No data for 002525.XSHE
# No data for 002710.XSHE
# No data for 002720.XSHE
# No data for 002941.XSHE
# No data for 002942.XSHE
# No data for 002943.XSHE
# No data for 300361.XSHE
# No data for 300646.XSHE
# No data for 300728.XSHE
# No data for 300752.XSHE
# No data for 300753.XSHE
# No data for 600349.XSHG
# No data for 600625.XSHG
# No data for 600632.XSHG
# No data for 600646.XSHG
# No data for 600669.XSHG
# No data for 600670.XSHG
# No data for 600709.XSHG
# No data for 600813.XSHG
# No data for 600878.XSHG
# No data for 601206.XSHG
# No data for 601860.XSHG
# No data for 603121.XSHG
# No data for 603187.XSHG
# No data for 603302.XSHG
# [20181127]
# 20181127 000065.XSHE 北方国际
# 20181127 000736.XSHE 中交地产
# 20181127 002007.XSHE 华兰生物
# 20181127 002010.XSHE 传化智联
# 20181127 002147.XSHE 新光圆成
# 20181127 002242.XSHE 九阳股份
# 20181127 002352.XSHE 顺丰控股
# 20181127 002399.XSHE 海普瑞
# 20181127 300009.XSHE 安科生物
# 20181127 300046.XSHE 台基股份
# 20181127 300240.XSHE 飞力达
# 20181127 300305.XSHE 裕兴股份
# 20181127 300400.XSHE 劲拓股份
# 20181127 300472.XSHE 新元科技
# 20181127 300512.XSHE 中亚股份
# 20181127 300600.XSHE 瑞特股份
# 20181127 300663.XSHE 科蓝软件
# 20181127 300668.XSHE 杰恩设计
# 20181127 600038.XSHG 中直股份
# 20181127 600273.XSHG 嘉化能源
# 20181127 600310.XSHG 桂东电力
# 20181127 600729.XSHG 重庆百货
# 20181127 600892.XSHG 大晟文化
# 20181127 601117.XSHG 中国化学
# 20181127 603045.XSHG 福达合金
# 20181127 603289.XSHG 泰瑞机器
# 20181127 603535.XSHG 嘉诚国际
# 20181127 603587.XSHG 地素时尚
# 20181127 603698.XSHG 航天工程
#
# 《结束选股》读取结束时间：==》n5 2018-11-28T10:20:52.737457

# %%
#MACD选股！tushare数据库

from matplotlib import rcParams
import matplotlib.pyplot as plt
import numpy as np
np.seterr(all='ignore')
rcParams['figure.figsize'] = (20, 20)

from funcat import * #FUNCAT的同花顺/通达信指标模块：和：&，或：|，其他基本相同。可以使用指标选股！！！
from tushare import * #TUSHARE数据连接更新。
from rqalpha import * #RQALPHA本地数据连接，通过 rqalpha update_bundle 8点后更新全部数据库

import time
import datetime #读取/设定数据库时间区域，当前股票，选股时间段。 

n1 = (time.strftime("20%y-%m-%d"))## 20yy-mm-dd格式，输出当日日期
print ("《设定测试》读取当日时间格式：n1",n1) #当日时间格式：yyyy-mm-dd
n2 = (time.strftime("20%y%m%d"))## 20yymmdd格式，输出当日日期
print ("《设定测试》读取当日时间格式：n2",n2) #当日时间格式：yyyymmdd
def getYesterday(): 
    today=datetime.date.today() 
    oneday=datetime.timedelta(days=1) 
    yesterday=today-oneday  
    return yesterday
n3 = (getYesterday())# 输出前二天日期
print ("《设定测试》读取前二日时间格式：n3",n3) #前日时间格式：yyyy-mm-dd
i = datetime.datetime.now()#当前日期

n4 = ("%s%s%s" % (i.year, i.month, i.day) )
print ("《设定测试》读取当日时间格式：n4",n4) #当日时间格式：yyyymmdd

n5 = ("%s" % i.isoformat() )
print ("《设定测试》读取当日时间格式：n5",n5) #当日时间格式：yyyy-mm-dd:...

n8="20180201"#开始时间
print ("《设定测试》手动设定选股开始时间格式：n8",n8)

n9="20180209"#结束时间
print ("《设定测试》手动设定选股结束时间格式：n9",n9)

def getYesterday(): 
    today=datetime.date.today() 
    oneday=datetime.timedelta(days=300) 
    yesterday=today-oneday  
    return yesterday
n10 = (getYesterday())# 输出前200天日期
#n10="20170101"#设定起始时间
print ("《设定测试》自动设定数据起始设定前推200天：n10",n10)

x1="000001.XSHG" #用rqalpha本地数据需要代码后缀！！！！XSHE=深圳，XSHG=上海
print ("《设定测试》设定股票代码",x1)

x2="002267.XSHE"

from funcat.data.tushare_backend import TushareDataBackend
from funcat.data.rqalpha_data_backend import RQAlphaDataBackend
backend = "tushare"  #设定数据库连接：rqalpha   tushare
if backend == "rqalpha":
    set_data_backend(RQAlphaDataBackend("~/.rqalpha/bundle"))
elif backend == "tushare":
    set_data_backend(TushareDataBackend())
set_start_date(n10)

S(x2)  # 设置当前关注股票
T(n3)   # 设置当前观察日期

print ("《数据测试》打印 开盘 最高 最低 收盘 成交量",O, H, L, C, V)  # 打印 Open High Low Close
print ("《数据测试》当天涨幅",C / C[1] - 1)  # 当天涨幅
print ("《数据测试》打印60日均线",MA(C, 60))  # 打印60日均线
print ("《数据测试》判断收盘价是否大于60日均线",C > MA(C, 60))  # 判断收盘价是否大于60日均线
print ("《数据测试》30日最高价",HHV(H, 30))  # 30日最高价
print ("《数据测试》最近30日，收盘价 Close 大于60日均线的天数",COUNT(C > MA(C, 60), 30))  # 最近30日，收盘价 Close 大于60日均线的天数
print ("《数据测试》10日均线上穿",CROSS(MA(C, 10), MA(C, 20)))  # 10日均线上穿
print ("《数据测试》最近10天收阳线的天数",COUNT(C > O, 10))  # 最近10天收阳线的天数
print ("《数据测试》最近60天K线实体的最高价",HHV(MAX(O, C), 60))  # 最近60天K线实体的最高价
print ("《数据测试》5日均线上穿10日均线",CROSS(MA(C, 5), MA(C, 10)))  # 5日均线上穿10日均线

# MACD 交易系统

DIFF = MA(L,12) - MA(L,26);
DEA  = MA(DIFF,9);
MACD = 1.618*(DIFF-DEA);
MACDMID = (DIFF-DEA)/1.618
OCHL = ((H+L)*(H-L)-(O+C)*(H-L))*MA(H,26)
ZERO = (C-O)*(H-L)*(O-C)*(L-H)

#ax = plt.subplot()
f, (ax1,ax2,ax3,ax4) = plt.subplots(4,1)

buy_signal = (CROSS(MACD, MACDMID) and CROSS(MACD,DIFF)) and DIFF<(MACDMID>0)>DEA #or CROSS(MACD,DIFF)
sell_signal = (CROSS(DIFF,MACDMID) or CROSS(DEA,DIFF)) and DIFF>MACDMID<MACD #or CROSS(MACDMID,MACD)

ax3.plot(H.series, label="H")
ax3.plot(L.series, label="L")
ax3.plot(C.series, label="C")
ax3.plot(O.series, label="O")
#ax3.set_xlim(0)

ax1.plot(OCHL.series, label="OCHL")
ax1.plot(ZERO.series, label="ZERO")

ax2.plot(ZERO.series, label="ZERO")

ax4.plot(MACDMID.series, label="MACDMID")
ax4.plot(MACD.series, label="MACD")
ax4.plot(DIFF.series, label="DIFF")
ax4.plot(DEA.series, label="DEA")
ax4.plot(ZERO.series, label="ZERO")

ax4.set_xlim(0)

plt.plot(np.where(buy_signal.series)[0], MACD.series[np.where(buy_signal.series)[0]], "^", label="buy", markersize=12, color="red")
plt.plot(np.where(sell_signal.series)[0], MACD.series[np.where(sell_signal.series)[0]], "v", label="sell", markersize=12, color="green")

plt.legend(loc="best")
plt.show()
# Out:
# 《设定测试》读取当日时间格式：n1 2018-11-28
# 《设定测试》读取当日时间格式：n2 20181128
# 《设定测试》读取前二日时间格式：n3 2018-11-27
# 《设定测试》读取当日时间格式：n4 20181128
# 《设定测试》读取当日时间格式：n5 2018-11-28T10:30:21.833509
# 《设定测试》手动设定选股开始时间格式：n8 20180201
# 《设定测试》手动设定选股结束时间格式：n9 20180209
# 《设定测试》自动设定数据起始设定前推200天：n10 2018-02-01
# 《设定测试》设定股票代码 000001.XSHG
# 《数据测试》打印 开盘 最高 最低 收盘 成交量 7.41 7.43 7.32 7.39 40116.0
# 《数据测试》当天涨幅 0.0013550135501354532
# 《数据测试》打印60日均线 7.504166666666669
# 《数据测试》判断收盘价是否大于60日均线 False
# 《数据测试》30日最高价 8.05
# 《数据测试》最近30日，收盘价 Close 大于60日均线的天数 16
# 《数据测试》10日均线上穿 False
# 《数据测试》最近10天收阳线的天数 4
# 《数据测试》最近60天K线实体的最高价 8.09
# 《数据测试》5日均线上穿10日均线 False

# %%
DIFF = (MA(L,12) - MA(L,26))
DEA  = (MA((MA(L,12) - MA(L,26)),9))
MACD = (2*((MA(L,12) - MA(L,26))-(MA((MA(L,12) - MA(L,26)),9))))
MACDMID = (((MA(L,12) - MA(L,26))-(MA((MA(L,12) - MA(L,26)),9)))/3)

CROSS((2*((MA(L,12) - MA(L,26))-(MA((MA(L,12) - MA(L,26)),9)))), (((MA(L,12) - MA(L,26))-(MA((MA(L,12) - MA(L,26)),9)))/3))


print ("《RQALPHA本地化开始选股》读取开始时间：==》n5",n5) 
# 选股MACD  OK!!!


select(
    lambda : CROSS((2*((MA(L,12) - MA(L,26))-(MA((MA(L,12) - MA(L,26)),9)))), (((MA(L,12) - MA(L,26))-(MA((MA(L,12) - MA(L,26)),9)))/3))

 ,
    start_date=(n3), end_date=(n2),
)

print ("《结束选股》读取结束时间：==》n5",n5)
# Out:
# 《RQALPHA本地化开始选股》读取开始时间：==》n5 2018-11-28T10:30:21.833509
# lambda : CROSS((2*((MA(L,12) - MA(L,26))-(MA((MA(L,12) - MA(L,26)),9)))), (((MA(L,12) - MA(L,26))-(MA((MA(L,12) - MA(L,26)),9)))/3))
# [20181127]
# 20181127 000065.XSHE 000065.XSHE[北方国际]
# 20181127 000736.XSHE 000736.XSHE[中交地产]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-9dac9d293a35> in <module>()
#      15
#      16  ,
# ---> 17     start_date=(n3), end_date=(n2),
#      18 )
#      19
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/funcat/helper.py in wrapper(*args, **kwargs)
#      15         try:
#      16             old_settings = np.seterr(all='ignore')
# ---> 17             return func(*args, **kwargs)
#      18         finally:
#      19             np.seterr(**old_settings)  # reset to default
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/funcat/helper.py in select(func, start_date, end_date, callback)
#      49
#      50         for order_book_id in order_book_id_list:
# ---> 51             choose(order_book_id, func, callback)
#      52
#      53     print("")
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/funcat/helper.py in choose(order_book_id, func, callback)
#      24     set_current_security(order_book_id)
#      25     try:
# ---> 26         if func():
#      27             date = ExecutionContext.get_current_date()
#      28             callback(date, order_book_id, symbol(order_book_id))
#
# <ipython-input-9-9dac9d293a35> in <lambda>()
#      12
#      13 select(
# ---> 14     lambda : CROSS((2*((MA(L,12) - MA(L,26))-(MA((MA(L,12) - MA(L,26)),9)))), (((MA(L,12) - MA(L,26))-(MA((MA(L,12) - MA(L,26)),9)))/3))
#      15
#      16  ,
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/funcat/func.py in __init__(self, series, arg)
#      25     def __init__(self, series, arg):
#      26         if isinstance(series, NumericSeries):
# ---> 27             series = series.series
#      28
#      29             try:
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/funcat/time_series.py in series(self)
#     270     @property
#     271     def series(self):
# --> 272         self._ensure_series_update()
#     273         return super(MarketDataSeries, self).series
#     274
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/funcat/time_series.py in _ensure_series_update(self)
#     246             # TODO: cache
#     247             freq = self._freq if self._freq is not None else ExecutionContext.get_current_freq()
# --> 248             bars = get_bars(freq)
#     249             if len(bars) > 0:
#     250                 self._series = bars[self.name].astype(self.dtype)
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/funcat/time_series.py in get_bars(freq)
#      18
#      19     try:
# ---> 20         bars = data_backend.get_price(order_book_id, start=start_date, end=current_date, freq=freq)
#      21     except KeyError:
#      22         return np.array([])
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/funcat/data/tushare_backend.py in get_price(self, order_book_id, start, end, freq)
#      66
#      67         del df["code"]
# ---> 68         arr = df.to_records()
#      69
#      70         return arr
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/pandas/core/frame.py in to_records(self, index, convert_datetime64)
#    1140         return np.rec.fromarrays(
#    1141             arrays,
# -> 1142             dtype={'names': names, 'formats': formats}
#    1143         )
#    1144
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/numpy/core/records.py in fromarrays(arrayList, dtype, shape, formats, names, titles, aligned, byteorder)
#     623             raise ValueError("array-shape mismatch in array %d" % k)
#     624
# --> 625     _array = recarray(shape, descr)
#     626
#     627     # populate the record array (makes a copy)
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/numpy/core/records.py in __new__(subtype, shape, dtype, buf, offset, strides, formats, names, titles, byteorder, aligned, order)
#     418
#     419         if buf is None:
# --> 420             self = ndarray.__new__(subtype, shape, (record, descr), order=order)
#     421         else:
#     422             self = ndarray.__new__(subtype, shape, (record, descr),
#
# /Volumes/QuantOsUSB/QuantOsUSB/rqalpha/Contents/Resources/venv/lib/python3.6/site-packages/numpy/core/records.py in __getattribute__(self, attr)
#     431             self.dtype = self.dtype
#     432
# --> 433     def __getattribute__(self, attr):
#     434         # See if ndarray has this attr, and return it if so. (note that this
#     435         # means a field with the same name as an ndarray attr cannot be
#
# KeyboardInterrupt:
